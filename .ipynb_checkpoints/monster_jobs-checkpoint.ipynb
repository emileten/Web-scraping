# %% [markdown]
# # Read websites info really, really fast: web-scraping in Python.

# %% [markdown]
# # Table of contents
#
# 1. [Terminology](#nt)

# %% [markdown]
# ## Terminology
# <a id="nt"> </a>

# %% [markdown]
#  A lot of technical jargon here. Here are definitions :
#
#  * BeautifulSoup : the Python library that contains web-scraping functions.
#  * Requests : the Python library that contains web-requests (https) functions.
#  * Web page :
#  * Website :
#  * Web server :
#  * Web browser :
#  * HTML : standard markup language on the web.
#  * DOM : Document Object Model. A tool provided by a web-browser to visualize a structured HTML.
#  * Static/Dynamic websites : in essence, a request to a static website returns a final content, an HTML ; in a dynamic website, it's a Javascript code that is ran locally by your web browser. More details below.

# %% [markdown]
# ## Static website

# %% [markdown]
# There's a lot of info on the web. We would like to collect and parse all of that but our lifespan is short. Hence, we web-scrape. How ? When you read a web page, you read the output of a code. Written, for example, in `HTML` language. Web scraping is, writing a code that collects chosen parts of that webpage's code and so systematically. How hard that task is, depends on how complex that code is. Basically there are two cases, assume the code is `HTML` language:
#  1. the server of a _static_ website returns all the page's `HTML` code you'll get to see as a user. All the info is there at once.
#  2. in a _dynamic_ website, the final code is usually `Javascript`. For memory purposes, many (dynamic) websites use `HTML` templates that are filled in with varying datasets. The output is a `Javascript` code that is processed locally by the browser.
#
# Let's start with the first case. We use the example from https://realpython.com/beautiful-soup-web-scraper-python/ : the **Monster Job** site.

# %% [markdown]
# ### Get the URL and the HTML code it leads to

# %% [markdown]
# The `requests` library in Python contains the tools to make `HTTP` requests through Python. I.e, whereas you would usually go to the URL section of your firefox or chrome window and type the URL of the website you want (actually, now you usually even just type a word because the search engine function is internalized...), `requests` does that for you in Python. Hence, it is the first step to web-scraping ! More in https://realpython.com/python-requests/

# %%
import requests #the library to make requests on the web (i.e, to look for things!)
from pprint import pprint  #to print (a bit more) prettily your request output.
from bs4 import BeautifulSoup #the library to process the output of requests. See below.

# %%
URL = 'https://www.monster.com/jobs/search/?q=Economist&where=USA'

# %%
page = requests.get(URL) #look for an URL. I.e, request it to the web server.

# %% [markdown]
# play around with the object `page` to see what's the point of `requests.get`. Look next : `status_code` returned a 200, which means your request was successful and the server responded with the data you were requesting.
#
# **Question** : **what does it mean if the output is 404? You've seen this a lot already...**

# %%
page.status_code #what is the status code of the HTTP request?
# Out:
# 200

# %% [markdown]
# Let's look at the HTML content of the page.

# %%
pprint(page.content) #what does the HTML look like ?
# Out:
# (b'<!DOCTYPE html>\r\n<html xmlns="https://www.w3.org/1999/xhtml" xml:lang="e'
#  b'n" lang="en">\r\n<head>\r\n    \r\n            <link rel="preconnect" href'
#  b'="https://coda.newjobs.com" />\r\n            <link rel="preconnect" href='
#  b'"https://js-seeker.newjobs.com" />\r\n            <link rel="preconnect" h'
#  b'ref="https://css-seeker.newjobs.com" />\r\n            <link rel="preconne'
#  b'ct" href="https://securemedia.newjobs.com" />\r\n            <link rel="pr'
#  b'econnect" href="https://logs2.jobs.com" />\r\n            <link rel="preco'
#  b'nnect" href="https://job-openings.monster.com" />\r\n            <link rel'
#  b'="preconnect" href="https://apis.google.com" />\r\n            <link rel="'
#  b'preconnect" href="https://www.google.com" />\r\n            <link rel="pre'
#  b'connect" href="https://accounts.google.com" />\r\n            <link rel="p'
#  b'reconnect" href="https://content.googleapis.com" />\r\n            <link r'
#  b'el="preconnect" href="https://ssl.gstatic.com" />\r\n            <link rel'
#  b'="preconnect" href="https://www.dropbox.com" />\r\n            <link rel="'
#  b'preconnect" href="http://js.live.net" />\r\n            <link rel="preconn'
#  b'ect" href="https://r.turn.com" />\r\n            <link rel="preconnect" hr'
#  b'ef="https://www.facebook.com" />\r\n            <link rel="preconnect" hre'
#  b'f="https://dpm.demdex.net" />\r\n            <link rel="preconnect" href="'
#  b'https://monster.demdex.net" />\r\n            <link rel="preconnect" href='
#  b'"https://fast.monster.demdex.net" />\r\n            <link rel="preconnect"'
#  b' href="https://logs.jobs.com" />\r\n            <link rel="preconnect" hre'
#  b'f="https://fonts.gstatic.com/" crossorigin />\r\n        <link rel="precon'
#  b'nect" href="https://cdnjs.cloudflare.com/" crossorigin />\r\n        <link'
#  b' rel="preconnect" href="https://netdna.bootstrapcdn.com/" crossorigin />'
#  b'\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge" />\r\n<meta http-eq'
#  b'uiv="Expires" content="0" />\r\n<meta name="viewport" content="width=devic'
#  b'e-width, initial-scale=1.0, maximum-scale=2.0, minimum-scale=1" />\r\n<met'
#  b'a name="j_jp" content="1" />\r\n<meta charset="UTF-8">\r\n<title>Economist J'
#  b'obs in USA. USA Economist Jobs. | Monster.com</title>\r\n\r\n        <style '
#  b'type="text/css">\r\n                @font-face{font-family:\'Roboto\';font-s'
#  b"tyle:normal;font-weight:100;font-display:optional;src:local('Roboto Thin'),l"
#  b"ocal('Roboto-Thin'),local('sans-serif-thin'),url(https://fonts.gstatic.com/s"
#  b"/roboto/v19/KFOkCnqEu92Fr1MmgVxFIzIXKMnyrYk.woff2) format('woff2');unicode-r"
#  b'ange:U+0460-052F,U+1C80-1C88,U+20B4,U+2DE0-2DFF,U+A640-A69F,U+FE2E-FE2F}@fon'
#  b"t-face{font-family:'Roboto';font-style:normal;font-weight:100;font-display:o"
#  b"ptional;src:local('Roboto Thin'),local('Roboto-Thin'),local('sans-serif-thin"
#  b"'),url(https://fonts.gstatic.com/s/roboto/v19/KFOkCnqEu92Fr1MmgVxMIzIXKMnyrY"
#  b"k.woff2) format('woff2');unicode-range:U+0400-045F,U+0490-0491,U+04B0-04B1,U"
#  b"+2116}@font-face{font-family:'Roboto';font-style:normal;font-weight:100;font"
#  b"-display:optional;src:local('Roboto Thin'),local('Roboto-Thin'),local('sans-"
#  b"serif-thin'),url(https://fonts.gstatic.com/s/roboto/v19/KFOkCnqEu92Fr1MmgVxE"
#  b"IzIXKMnyrYk.woff2) format('woff2');unicode-range:U+1F00-1FFF}@font-face{font"
#  b"-family:'Roboto';font-style:normal;font-weight:100;font-display:optional;src"
#  b":local('Roboto Thin'),local('Roboto-Thin'),local('sans-serif-thin'),url(http"
#  b's://fonts.gstatic.com/s/roboto/v19/KFOkCnqEu92Fr1MmgVxLIzIXKMnyrYk.woff2) fo'
#  b"rmat('woff2');unicode-range:U+0370-03FF}@font-face{font-family:'Roboto';font"
#  b"-style:normal;font-weight:100;font-display:optional;src:local('Roboto Thin')"
#  b",local('Roboto-Thin'),local('sans-serif-thin'),url(https://fonts.gstatic.com"
#  b"/s/roboto/v19/KFOkCnqEu92Fr1MmgVxHIzIXKMnyrYk.woff2) format('woff2');unicode"
#  b"-range:U+0102-0103,U+0110-0111,U+1EA0-1EF9,U+20AB}@font-face{font-family:'Ro"
#  b"boto';font-style:normal;font-weight:100;font-display:optional;src:local('Rob"
#  b"oto Thin'),local('Roboto-Thin'),local('sans-serif-thin'),url(https://fonts.g"
#  b"static.com/s/roboto/v19/KFOkCnqEu92Fr1MmgVxGIzIXKMnyrYk.woff2) format('woff2"
#  b"');unicode-range:U+0100-024F,U+0259,U+1E00-1EFF,U+2020,U+20A0-20AB,U+20AD-20"
#  b"CF,U+2113,U+2C60-2C7F,U+A720-A7FF}@font-face{font-family:'Roboto';font-style"
#  b":normal;font-weight:100;font-display:optional;src:local('Roboto Thin'),local"
#  b"('Roboto-Thin'),local('sans-serif-thin'),url(https://fonts.gstatic.com/s/rob"
#  b"oto/v19/KFOkCnqEu92Fr1MmgVxIIzIXKMny.woff2) format('woff2');unicode-range:U+"
#  b'0000-00FF,U+0131,U+0152-0153,U+02BB-02BC,U+02C6,U+02DA,U+02DC,U+2000-206F,U+'
#  b'2074,U+20AC,U+2122,U+2191,U+2193,U+2212,U+2215,U+FEFF,U+FFFD}@font-face{font'
#  b"-family:'Roboto';font-style:normal;font-weight:300;font-display:optional;src"
#  b":local('Roboto Light'),local('Roboto-Light'),local('sans-serif-light'),url(h"
#  b'ttps://fonts.gstatic.com/s/roboto/v19/KFOlCnqEu92Fr1MmSU5fCRc4AMP6lbBP.woff2'
#  b") format('woff2');unicode-range:U+0460-052F,U+1C80-1C88,U+20B4,U+2DE0-2DFF,U"
#  b"+A640-A69F,U+FE2E-FE2F}@font-face{font-family:'Roboto';font-style:normal;fon"
#  b"t-weight:300;font-display:optional;src:local('Roboto Light'),local('Roboto-L"
#  b"ight'),local('sans-serif-light'),url(https://fonts.gstatic.com/s/roboto/v19/"
#  b"KFOlCnqEu92Fr1MmSU5fABc4AMP6lbBP.woff2) format('woff2');unicode-range:U+0400"
#  b"-045F,U+0490-0491,U+04B0-04B1,U+2116}@font-face{font-family:'Roboto';font-st"
#  b"yle:normal;font-weight:300;font-display:optional;src:local('Roboto Light'),l"
#  b"ocal('Roboto-Light'),local('sans-serif-light'),url(https://fonts.gstatic.com"
#  b"/s/roboto/v19/KFOlCnqEu92Fr1MmSU5fCBc4AMP6lbBP.woff2) format('woff2');unicod"
#  b"e-range:U+1F00-1FFF}@font-face{font-family:'Roboto';font-style:normal;font-w"
#  b"eight:300;font-display:optional;src:local('Roboto Light'),local('Roboto-Ligh"
#  b"t'),local('sans-serif-light'),url(https://fonts.gstatic.com/s/roboto/v19/KFO"
#  b"lCnqEu92Fr1MmSU5fBxc4AMP6lbBP.woff2) format('woff2');unicode-range:U+0370-03"
#  b"FF}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;font-di"
#  b"splay:optional;src:local('Roboto Light'),local('Roboto-Light'),local('sans-s"
#  b"erif-light'),url(https://fonts.gstatic.com/s/roboto/v19/KFOlCnqEu92Fr1MmSU5f"
#  b"Cxc4AMP6lbBP.woff2) format('woff2');unicode-range:U+0102-0103,U+0110-0111,U+"
#  b"1EA0-1EF9,U+20AB}@font-face{font-family:'Roboto';font-style:normal;font-weig"
#  b"ht:300;font-display:optional;src:local('Roboto Light'),local('Roboto-Light')"
#  b",local('sans-serif-light'),url(https://fonts.gstatic.com/s/roboto/v19/KFOlCn"
#  b"qEu92Fr1MmSU5fChc4AMP6lbBP.woff2) format('woff2');unicode-range:U+0100-024F,"
#  b'U+0259,U+1E00-1EFF,U+2020,U+20A0-20AB,U+20AD-20CF,U+2113,U+2C60-2C7F,U+A720-'
#  b"A7FF}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;font-"
#  b"display:optional;src:local('Roboto Light'),local('Roboto-Light'),local('sans"
#  b"-serif-light'),url(https://fonts.gstatic.com/s/roboto/v19/KFOlCnqEu92Fr1MmSU"
#  b"5fBBc4AMP6lQ.woff2) format('woff2');unicode-range:U+0000-00FF,U+0131,U+0152-"
#  b'0153,U+02BB-02BC,U+02C6,U+02DA,U+02DC,U+2000-206F,U+2074,U+20AC,U+2122,U+219'
#  b"1,U+2193,U+2212,U+2215,U+FEFF,U+FFFD}@font-face{font-family:'Roboto';font-st"
#  b"yle:normal;font-weight:400;font-display:optional;src:local('Roboto'),local('"
#  b"Roboto-Regular'),local('sans-serif'),url(https://fonts.gstatic.com/s/roboto/"
#  b"v19/KFOmCnqEu92Fr1Mu72xKKTU1Kvnz.woff2) format('woff2');unicode-range:U+0460"
#  b'-052F,U+1C80-1C88,U+20B4,U+2DE0-2DFF,U+A640-A69F,U+FE2E-FE2F}@font-face{font'
#  b"-family:'Roboto';font-style:normal;font-weight:400;font-display:optional;src"
#  b":local('Roboto'),local('Roboto-Regular'),local('sans-serif'),url(https://fon"
#  b"ts.gstatic.com/s/roboto/v19/KFOmCnqEu92Fr1Mu5mxKKTU1Kvnz.woff2) format('woff"
#  b"2');unicode-range:U+0400-045F,U+0490-0491,U+04B0-04B1,U+2116}@font-face{font"
#  b"-family:'Roboto';font-style:normal;font-weight:400;font-display:optional;src"
#  b":local('Roboto'),local('Roboto-Regular'),local('sans-serif'),url(https://fon"
#  b"ts.gstatic.com/s/roboto/v19/KFOmCnqEu92Fr1Mu7mxKKTU1Kvnz.woff2) format('woff"
#  b"2');unicode-range:U+1F00-1FFF}@font-face{font-family:'Roboto';font-style:nor"
#  b"mal;font-weight:400;font-display:optional;src:local('Roboto'),local('Roboto-"
#  b"Regular'),local('sans-serif'),url(https://fonts.gstatic.com/s/roboto/v19/KFO"
#  b"mCnqEu92Fr1Mu4WxKKTU1Kvnz.woff2) format('woff2');unicode-range:U+0370-03FF}@"
#  b"font-face{font-family:'Roboto';font-style:normal;font-weight:400;font-displa"
#  b"y:optional;src:local('Roboto'),local('Roboto-Regular'),local('sans-serif'),u"
#  b'rl(https://fonts.gstatic.com/s/roboto/v19/KFOmCnqEu92Fr1Mu7WxKKTU1Kvnz.woff2'
#  b") format('woff2');unicode-range:U+0102-0103,U+0110-0111,U+1EA0-1EF9,U+20AB}@"
#  b"font-face{font-family:'Roboto';font-style:normal;font-weight:400;font-displa"
#  b"y:optional;src:local('Roboto'),local('Roboto-Regular'),local('sans-serif'),u"
#  b'rl(https://fonts.gstatic.com/s/roboto/v19/KFOmCnqEu92Fr1Mu7GxKKTU1Kvnz.woff2'
#  b") format('woff2');unicode-range:U+0100-024F,U+0259,U+1E00-1EFF,U+2020,U+20A0"
#  b"-20AB,U+20AD-20CF,U+2113,U+2C60-2C7F,U+A720-A7FF}@font-face{font-family:'Rob"
#  b"oto';font-style:normal;font-weight:400;font-display:optional;src:local('Robo"
#  b"to'),local('Roboto-Regular'),local('sans-serif'),url(https://fonts.gstatic.c"
#  b"om/s/roboto/v19/KFOmCnqEu92Fr1Mu4mxKKTU1Kg.woff2) format('woff2');unicode-ra"
#  b'nge:U+0000-00FF,U+0131,U+0152-0153,U+02BB-02BC,U+02C6,U+02DA,U+02DC,U+2000-2'
#  b'06F,U+2074,U+20AC,U+2122,U+2191,U+2193,U+2212,U+2215,U+FEFF,U+FFFD}@font-fac'
#  b"e{font-family:'Roboto';font-style:normal;font-weight:500;font-display:option"
#  b"al;src:local('Roboto Medium'),local('Roboto-Medium'),local('sans-serif-mediu"
#  b"m'),url(https://fonts.gstatic.com/s/roboto/v19/KFOlCnqEu92Fr1MmEU9fCRc4AMP6l"
#  b"bBP.woff2) format('woff2');unicode-range:U+0460-052F,U+1C80-1C88,U+20B4,U+2D"
#  b"E0-2DFF,U+A640-A69F,U+FE2E-FE2F}@font-face{font-family:'Roboto';font-style:n"
#  b"ormal;font-weight:500;font-display:optional;src:local('Roboto Medium'),local"
#  b"('Roboto-Medium'),local('sans-serif-medium'),url(https://fonts.gstatic.com/s"
#  b"/roboto/v19/KFOlCnqEu92Fr1MmEU9fABc4AMP6lbBP.woff2) format('woff2');unicode-"
#  b"range:U+0400-045F,U+0490-0491,U+04B0-04B1,U+2116}@font-face{font-family:'Rob"
#  b"oto';font-style:normal;font-weight:500;font-display:optional;src:local('Robo"
#  b"to Medium'),local('Roboto-Medium'),local('sans-serif-medium'),url(https://fo"
#  b'nts.gstatic.com/s/roboto/v19/KFOlCnqEu92Fr1MmEU9fCBc4AMP6lbBP.woff2) format('
#  b"'woff2');unicode-range:U+1F00-1FFF}@font-face{font-family:'Roboto';font-styl"
#  b"e:normal;font-weight:500;font-display:optional;src:local('Roboto Medium'),lo"
#  b"cal('Roboto-Medium'),local('sans-serif-medium'),url(https://fonts.gstatic.co"
#  b"m/s/roboto/v19/KFOlCnqEu92Fr1MmEU9fBxc4AMP6lbBP.woff2) format('woff2');unico"
#  b"de-range:U+0370-03FF}@font-face{font-family:'Roboto';font-style:normal;font-"
#  b"weight:500;font-display:optional;src:local('Roboto Medium'),local('Roboto-Me"
#  b"dium'),local('sans-serif-medium'),url(https://fonts.gstatic.com/s/roboto/v19"
#  b"/KFOlCnqEu92Fr1MmEU9fCxc4AMP6lbBP.woff2) format('woff2');unicode-range:U+010"
#  b"2-0103,U+0110-0111,U+1EA0-1EF9,U+20AB}@font-face{font-family:'Roboto';font-s"
#  b"tyle:normal;font-weight:500;font-display:optional;src:local('Roboto Medium')"
#  b",local('Roboto-Medium'),local('sans-serif-medium'),url(https://fonts.gstatic"
#  b".com/s/roboto/v19/KFOlCnqEu92Fr1MmEU9fChc4AMP6lbBP.woff2) format('woff2');un"
#  b'icode-range:U+0100-024F,U+0259,U+1E00-1EFF,U+2020,U+20A0-20AB,U+20AD-20CF,U+'
#  b"2113,U+2C60-2C7F,U+A720-A7FF}@font-face{font-family:'Roboto';font-style:norm"
#  b"al;font-weight:500;font-display:optional;src:local('Roboto Medium'),local('R"
#  b"oboto-Medium'),local('sans-serif-medium'),url(https://fonts.gstatic.com/s/ro"
#  b"boto/v19/KFOlCnqEu92Fr1MmEU9fBBc4AMP6lQ.woff2) format('woff2');unicode-range"
#  b':U+0000-00FF,U+0131,U+0152-0153,U+02BB-02BC,U+02C6,U+02DA,U+02DC,U+2000-206F'
#  b',U+2074,U+20AC,U+2122,U+2191,U+2193,U+2212,U+2215,U+FEFF,U+FFFD}@font-face{f'
#  b"ont-family:'HCo Champion Middlewt';font-display:wrap;src:url(https://media.n"
#  b"ewjobs.com/homepage/fonts/Champion-Middleweight_Web.woff2) format('woff2'),u"
#  b'rl(https://media.newjobs.com/homepage/fonts/Champion-Middleweight_Web.woff) '
#  b'format(\'woff\');\r\n        </style>\r\n\r\n    <style type="text/css">'
#  b'\r\n            \r\n\r\n@font-face{font-family:"Material Design Icons";src'
#  b':url("https://securemedia.newjobs.com/global/fonts/materialdesignicons-1.9.3'
#  b'2/materialdesignicons-webfont.eot?v=1.9.32");src:url("https://securemedia.ne'
#  b'wjobs.com/global/fonts/materialdesignicons-1.9.32/materialdesignicons-webfon'
#  b't.eot?#iefix&v=1.9.32") format("embedded-opentype"),url("https://securemedia'
#  b'.newjobs.com/global/fonts/materialdesignicons-1.9.32/materialdesignicons-web'
#  b'font.woff2?v=1.9.32") format("woff2"),url("https://securemedia.newjobs.com/g'
#  b'lobal/fonts/materialdesignicons-1.9.32/materialdesignicons-webfont.woff?v=1.'
#  b'9.32") format("woff"),url("https://securemedia.newjobs.com/global/fonts/mate'
#  b'rialdesignicons-1.9.32/materialdesignicons-webfont.ttf?v=1.9.32") format("tr'
#  b'uetype"),url("https://securemedia.newjobs.com/global/fonts/materialdesignico'
#  b'ns-1.9.32/materialdesignicons-webfont.svg?v=1.9.32#materialdesigniconsregula'
#  b'r") format("svg");font-weight:400;font-style:normal;font-display:swap;}.mdi:'
#  b':before{display:inline-block;font-style:normal;font-variant:normal;font-weig'
#  b"ht:400;font-family:'Material Design Icons';font-size:inherit;text-rendering:"
#  b'auto;line-height:inherit;-webkit-font-smoothing:antialiased}.mdi-magnify::be'
#  b'fore{content:"\\f349"}.mdi-map-marker::before{content:"\\f34e"}html{font-f'
#  b'amily:sans-serif}body{margin:0}header,main,nav,section{display:block}a{backg'
#  b'round-position:0 0;background-repeat:initial initial}h1{font-size:2em;margin'
#  b':.67em 0}button,input,select{color:inherit;font-family:inherit;font-size:inh'
#  b'erit;font-style:inherit;font-variant:inherit;font-weight:inherit;line-height'
#  b':inherit;margin:0}button{overflow:visible}button,select{text-transform:none}'
#  b'button{-webkit-appearance:button}input{line-height:normal}input[type="checkb'
#  b'ox"]{box-sizing:border-box;padding:0}*{box-sizing:border-box}::before,::afte'
#  b"r{box-sizing:border-box}html{font-size:62.5%}body{font-family:'Helvetica Neu"
#  b"e',Helvetica,Arial,sans-serif;font-size:14px;line-height:1.42857143;color:rg"
#  b'b(51,51,51);background-color:rgb(255,255,255)}input,button,select{font-famil'
#  b'y:inherit;font-size:inherit;line-height:inherit}a{color:rgb(66,139,202);text'
#  b'-decoration:none}.sr-only{position:absolute;width:1px;height:1px;margin:-1px'
#  b';padding:0;overflow:hidden;clip:rect(0 0 0 0);border:0}h1,h2,h3,h4{font-fami'
#  b'ly:inherit;font-weight:500;line-height:1.1;color:inherit}h1,h2,h3{margin-top'
#  b':20px;margin-bottom:10px}h4{margin-top:10px;margin-bottom:10px}h1{font-size:'
#  b'36px}h2{font-size:30px}h3{font-size:24px}h4{font-size:18px}p{margin:0 0 10px'
#  b'}.lead{margin-bottom:20px;font-size:16px;font-weight:200;line-height:1.4}@me'
#  b'dia (min-width:768px){.lead{font-size:21px}}.text-center{text-align:center}u'
#  b'l{margin-top:0;margin-bottom:10px}ul ul{margin-bottom:0}.list-inline{padding'
#  b'-left:0;list-style:none;margin-left:-5px}.container{margin-right:auto;margin'
#  b'-left:auto;padding-left:15px;padding-right:15px}@media (min-width:768px){.co'
#  b'ntainer{width:750px}}@media (min-width:992px){.container{width:970px}}@media'
#  b' (min-width:1200px){.container{width:1170px}}.container-fluid{margin-right:a'
#  b'uto;margin-left:auto;padding-left:15px;padding-right:15px}.row{margin-left:-'
#  b'15px;margin-right:-15px}.col-md-4,.col-sm-6,.col-md-8{position:relative;min-'
#  b'height:1px;padding-left:15px;padding-right:15px}@media (min-width:768px){.co'
#  b'l-sm-6{float:left}.col-sm-6{width:50%}}@media (min-width:992px){.col-md-4,.c'
#  b'ol-md-8{float:left}.col-md-8{width:66.66666667%}.col-md-4{width:33.33333333%'
#  b'}}label{display:inline-block;margin-bottom:5px;font-weight:700}input[type="c'
#  b'heckbox"]{margin:4px 0 0;line-height:normal}.form-control{display:block;widt'
#  b'h:100%;height:34px;padding:6px 12px;font-size:14px;line-height:1.42857143;co'
#  b'lor:rgb(85,85,85);background-color:rgb(255,255,255);background-image:none;bo'
#  b'rder:1px solid rgb(204,204,204);border-top-left-radius:4px;border-top-right-'
#  b'radius:4px;border-bottom-right-radius:4px;border-bottom-left-radius:4px;-web'
#  b'kit-box-shadow:rgba(0,0,0,.0745098) 0 1px 1px inset;box-shadow:rgba(0,0,0,.0'
#  b'745098) 0 1px 1px inset}.form-control::-webkit-input-placeholder{color:rgb(1'
#  b'53,153,153)}.form-control[disabled]{background-color:rgb(238,238,238);opacit'
#  b'y:1}.form-group{margin-bottom:15px}.checkbox{display:block;min-height:20px;m'
#  b'argin-top:10px;margin-bottom:10px;padding-left:20px}.checkbox label{display:'
#  b'inline;font-weight:400}.checkbox input[type="checkbox"]{float:left;margin-le'
#  b'ft:-20px}.input-sm{height:30px;padding:5px 10px;font-size:12px;line-height:1'
#  b'.5;border-top-left-radius:3px;border-top-right-radius:3px;border-bottom-righ'
#  b't-radius:3px;border-bottom-left-radius:3px}@media (min-width:768px){.form-in'
#  b'line .form-group{display:inline-block;margin-bottom:0;vertical-align:middle}'
#  b'.form-inline .form-control{display:inline-block;width:auto;vertical-align:mi'
#  b'ddle}.form-inline .control-label{margin-bottom:0;vertical-align:middle}.form'
#  b'-inline .checkbox{display:inline-block;margin-top:0;margin-bottom:0;padding-'
#  b'left:0;vertical-align:middle}.form-inline .checkbox input[type="checkbox"]{f'
#  b'loat:none;margin-left:0}}.btn{display:inline-block;margin-bottom:0;font-weig'
#  b'ht:400;text-align:center;vertical-align:middle;background-image:none;border:'
#  b'1px solid transparent;white-space:nowrap;padding:6px 12px;font-size:14px;lin'
#  b'e-height:1.42857143;border-top-left-radius:4px;border-top-right-radius:4px;b'
#  b'order-bottom-right-radius:4px;border-bottom-left-radius:4px}.btn-primary{col'
#  b'or:rgb(255,255,255);background-color:rgb(66,139,202);border-color:rgb(53,126'
#  b',189)}.btn-link{color:rgb(66,139,202);font-weight:400;border-top-left-radius'
#  b':0;border-top-right-radius:0;border-bottom-right-radius:0;border-bottom-left'
#  b'-radius:0}.btn-link{background-color:transparent;-webkit-box-shadow:none;box'
#  b'-shadow:none}.btn-link{border-color:transparent}.btn-sm{padding:5px 10px;fon'
#  b't-size:12px;line-height:1.5;border-top-left-radius:3px;border-top-right-radi'
#  b'us:3px;border-bottom-right-radius:3px;border-bottom-left-radius:3px}.collaps'
#  b'e{display:none}.caret{display:inline-block;width:0;height:0;margin-left:2px;'
#  b'vertical-align:middle;border-top-width:4px;border-top-style:solid;border-rig'
#  b'ht-width:4px;border-right-style:solid;border-right-color:transparent;border-'
#  b'left-width:4px;border-left-style:solid;border-left-color:transparent}.dropdo'
#  b'wn{position:relative}.dropdown-menu{position:absolute;top:100%;left:0;z-inde'
#  b'x:1000;display:none;float:left;min-width:160px;padding:5px 0;margin:2px 0 0;'
#  b'list-style:none;font-size:14px;background-color:rgb(255,255,255);border:1px '
#  b'solid rgba(0,0,0,.14902);border-top-left-radius:4px;border-top-right-radius:'
#  b'4px;border-bottom-right-radius:4px;border-bottom-left-radius:4px;-webkit-box'
#  b'-shadow:rgba(0,0,0,.172549) 0 6px 12px;box-shadow:rgba(0,0,0,.172549) 0 6px '
#  b'12px;background-clip:padding-box}.dropdown-menu>li>a{display:block;padding:3'
#  b'px 20px;clear:both;font-weight:400;line-height:1.42857143;color:rgb(51,51,51'
#  b');white-space:nowrap}@media (min-width:768px){.navbar-right .dropdown-menu{l'
#  b'eft:auto;right:0}}.input-group{position:relative;display:table;border-collap'
#  b'se:separate}.input-group .form-control{position:relative;z-index:2;float:lef'
#  b't;width:100%;margin-bottom:0}.input-group-sm>.form-control,.input-group-sm>.'
#  b'input-group-addon{height:30px;padding:5px 10px;font-size:12px;line-height:1.'
#  b'5;border-top-left-radius:3px;border-top-right-radius:3px;border-bottom-right'
#  b'-radius:3px;border-bottom-left-radius:3px}.input-group-addon,.input-group .f'
#  b'orm-control{display:table-cell}.input-group .form-control:not(:first-child):'
#  b'not(:last-child){border-top-left-radius:0;border-top-right-radius:0;border-b'
#  b'ottom-right-radius:0;border-bottom-left-radius:0}.input-group-addon{width:1%'
#  b';white-space:nowrap;vertical-align:middle}.input-group-addon:first-child{bor'
#  b'der-bottom-right-radius:0;border-top-right-radius:0}.input-group-addon:first'
#  b'-child{border-right-width:0}.nav{margin-bottom:0;padding-left:0;list-style:n'
#  b'one}.nav>li{position:relative;display:block}.nav>li>a{position:relative;disp'
#  b'lay:block;padding:10px 15px}.navbar{position:relative;min-height:50px;margin'
#  b'-bottom:20px;border:1px solid transparent}@media (min-width:768px){.navbar{b'
#  b'order-top-left-radius:4px;border-top-right-radius:4px;border-bottom-right-ra'
#  b'dius:4px;border-bottom-left-radius:4px}}@media (min-width:768px){.navbar-hea'
#  b'der{float:left}}.navbar-collapse{max-height:340px;overflow-x:visible;padding'
#  b'-right:15px;padding-left:15px;border-top-width:1px;border-top-style:solid;bo'
#  b'rder-top-color:transparent;box-shadow:rgba(255,255,255,.0980392) 0 1px 0 ins'
#  b'et}@media (min-width:768px){.navbar-collapse{width:auto;border-top-width:0;b'
#  b'ox-shadow:none}.navbar-collapse.collapse{padding-bottom:0;display:block!impo'
#  b'rtant;height:auto!important;overflow:visible!important}.navbar-fixed-top .na'
#  b'vbar-collapse{padding-left:0;padding-right:0}}.container-fluid>.navbar-heade'
#  b'r,.container-fluid>.navbar-collapse{margin-right:-15px;margin-left:-15px}@me'
#  b'dia (min-width:768px){.container-fluid>.navbar-header,.container-fluid>.navb'
#  b'ar-collapse{margin-right:0;margin-left:0}}.navbar-fixed-top{position:fixed;r'
#  b'ight:0;left:0;z-index:1030}@media (min-width:768px){.navbar-fixed-top{border'
#  b'-top-left-radius:0;border-top-right-radius:0;border-bottom-right-radius:0;bo'
#  b'rder-bottom-left-radius:0}}.navbar-fixed-top{top:0;border-width:0 0 1px}.nav'
#  b'bar-brand{float:left;padding:15px;font-size:18px;line-height:20px;height:50p'
#  b'x}@media (min-width:768px){.navbar>.container-fluid .navbar-brand{margin-lef'
#  b't:-15px}}.navbar-toggle{position:relative;float:right;margin-right:15px;padd'
#  b'ing:9px 10px;margin-top:8px;margin-bottom:8px;background-color:transparent;b'
#  b'ackground-image:none;border:1px solid transparent;border-top-left-radius:4px'
#  b';border-top-right-radius:4px;border-bottom-right-radius:4px;border-bottom-le'
#  b'ft-radius:4px}.navbar-toggle .icon-bar{display:block;width:22px;height:2px;b'
#  b'order-top-left-radius:1px;border-top-right-radius:1px;border-bottom-right-ra'
#  b'dius:1px;border-bottom-left-radius:1px}.navbar-toggle .icon-bar+.icon-bar{ma'
#  b'rgin-top:4px}@media (min-width:768px){.navbar-toggle{display:none}}.navbar-n'
#  b'av{margin:7.5px -15px}.navbar-nav>li>a{padding-top:10px;padding-bottom:10px;'
#  b'line-height:20px}@media (min-width:768px){.navbar-nav{float:left;margin:0}.n'
#  b'avbar-nav>li{float:left}.navbar-nav>li>a{padding-top:15px;padding-bottom:15p'
#  b'x}.navbar-nav.navbar-right:last-child{margin-right:-15px}}@media (min-width:'
#  b'768px){.navbar-right{float:right!important}}.navbar-form{margin:8px -15px;pa'
#  b'dding:10px 15px;border-top-width:1px;border-top-style:solid;border-top-color'
#  b':transparent;border-bottom-width:1px;border-bottom-style:solid;border-bottom'
#  b'-color:transparent;-webkit-box-shadow:rgba(255,255,255,.0980392) 0 1px 0 ins'
#  b'et,rgba(255,255,255,.0980392) 0 1px 0;box-shadow:rgba(255,255,255,.0980392) '
#  b'0 1px 0 inset,rgba(255,255,255,.0980392) 0 1px 0}@media (min-width:768px){.n'
#  b'avbar-form .form-group{display:inline-block;margin-bottom:0;vertical-align:m'
#  b'iddle}.navbar-form .form-control{display:inline-block;width:auto;vertical-al'
#  b'ign:middle}.navbar-form .input-group>.form-control{width:100%}}@media (max-w'
#  b'idth:767px){.navbar-form .form-group{margin-bottom:5px}}@media (min-width:76'
#  b'8px){.navbar-form{width:auto;border:0;margin-left:0;margin-right:0;padding-t'
#  b'op:0;padding-bottom:0;-webkit-box-shadow:none;box-shadow:none}}.navbar-nav>l'
#  b'i>.dropdown-menu{margin-top:0;border-top-right-radius:0;border-top-left-radi'
#  b'us:0}.navbar-text{margin-top:15px;margin-bottom:15px}@media (min-width:768px'
#  b'){.navbar-text{float:left;margin-left:15px;margin-right:15px}}.navbar-defaul'
#  b't{background-color:rgb(248,248,248);border-color:rgb(231,231,231)}.navbar-de'
#  b'fault .navbar-brand{color:rgb(119,119,119)}.navbar-default .navbar-text{colo'
#  b'r:rgb(119,119,119)}.navbar-default .navbar-nav>li>a{color:rgb(119,119,119)}.'
#  b'navbar-default .navbar-toggle{border-color:rgb(221,221,221)}.navbar-default '
#  b'.navbar-toggle .icon-bar{background-color:rgb(136,136,136)}.navbar-default .'
#  b'navbar-collapse,.navbar-default .navbar-form{border-color:rgb(231,231,231)}.'
#  b'thumbnail{display:block;padding:4px;margin-bottom:20px;line-height:1.4285714'
#  b'3;background-color:rgb(255,255,255);border:1px solid rgb(221,221,221);border'
#  b'-top-left-radius:4px;border-top-right-radius:4px;border-bottom-right-radius:'
#  b'4px;border-bottom-left-radius:4px}.clearfix::before,.clearfix::after,.contai'
#  b'ner::before,.container::after,.container-fluid::before,.container-fluid::aft'
#  b'er,.row::before,.row::after,.nav::before,.nav::after,.navbar::before,.navbar'
#  b'::after,.navbar-header::before,.navbar-header::after,.navbar-collapse::befor'
#  b"e,.navbar-collapse::after{content:' ';display:table}.clearfix::after,.contai"
#  b'ner::after,.container-fluid::after,.row::after,.nav::after,.navbar::after,.n'
#  b'avbar-header::after,.navbar-collapse::after{clear:both}.center-block{display'
#  b':block;margin-left:auto;margin-right:auto}.hide{display:none!important}.hidd'
#  b'en{display:none!important;visibility:hidden!important}@media (max-width:767p'
#  b'x){.hidden-xs{display:none!important}}@media (max-width:991px) and (min-widt'
#  b'h:768px){.hidden-sm{display:none!important}}@media (max-width:1199px) and (m'
#  b'in-width:992px){.hidden-md{display:none!important}}@media (min-width:1200px)'
#  b'{.hidden-lg{display:none!important}}@font-face{font-family:FontAwesome;src:u'
#  b'rl(https://securemedia.newjobs.com/global/fonts/fontawesome-4.5.0/fontawesom'
#  b"e-webfont.eot?#iefix&v=4.5.0) format('embedded-opentype'),url(https://secure"
#  b'media.newjobs.com/global/fonts/fontawesome-4.5.0/fontawesome-webfont.woff2?v'
#  b"=4.5.0) format('woff2'),url(https://securemedia.newjobs.com/global/fonts/fon"
#  b"tawesome-4.5.0/fontawesome-webfont.woff?v=4.5.0) format('woff'),url(https://"
#  b'securemedia.newjobs.com/global/fonts/fontawesome-4.5.0/fonts/fontawesome-web'
#  b"font.ttf?v=4.5.0) format('truetype'),url(https://securemedia.newjobs.com/glo"
#  b'bal/fonts/fontawesome-4.5.0/fontawesome-webfont.svg?v=4.5.0#fontawesomeregul'
#  b"ar) format('svg');font-weight:400;font-style:normal;font-display:swap;}.fa{d"
#  b'isplay:inline-block;font-style:normal;font-variant:normal;font-weight:400;li'
#  b'ne-height:1;font-family:FontAwesome;font-size:inherit;text-rendering:auto;-w'
#  b"ebkit-font-smoothing:antialiased}.fa-times::before{content:'\\f00d'}.fa-s"
#  b"earch::before{content:'\\f002'}body{padding-top:125px;margin-top:0}.navba"
#  b'r *{font-weight:400;text-shadow:none}.navbar{background-image:none;border-to'
#  b'p-left-radius:0;border-top-right-radius:0;border-bottom-right-radius:0;borde'
#  b'r-bottom-left-radius:0;min-width:310px;-webkit-box-shadow:rgba(0,0,0,.2) 0 0'
#  b' 1px;box-shadow:rgba(0,0,0,.2) 0 0 1px}.navbar.solid-nav{background-color:rg'
#  b'b(255,255,255);border:none}.logo-new-branding-g-header{position:relative;bac'
#  b'kground-size:180px;width:180px;height:30px;background-repeat:no-repeat no-re'
#  b'peat}.navbar.solid-nav .navbar-main{padding-top:14px;background-color:rgb(25'
#  b'5,255,255);background-position:initial initial;background-repeat:initial ini'
#  b'tial}.navbar.solid-nav .navbar-text{color:rgba(0,0,0,.870588);font-weight:40'
#  b'0;background-image:none;font-size:16px;margin:0;background-position:initial '
#  b'initial;background-repeat:initial initial}.navbar.solid-nav .keywords,.navba'
#  b'r.solid-nav .location{position:relative;border:1px solid #6E46AE}.navbar.sol'
#  b'id-nav .input-group{background-image:none;border-top-left-radius:3px;border-'
#  b'top-right-radius:3px;border-bottom-right-radius:3px;border-bottom-left-radiu'
#  b's:3px;width:100%;background-position:initial initial;background-repeat:initi'
#  b'al initial}.navbar.solid-nav .input-group .form-control{width:90%}.navbar.so'
#  b'lid-nav .input-group .form-control,.navbar.solid-nav .input-group .input-gro'
#  b'up-addon{color:#6E46AE}.navbar.solid-nav .input-group .input-group-addon i{c'
#  b'olor:#6E46AE;margin-right:0}.navbar.solid-nav .input-group .typeahead{width:'
#  b'100%}.navbar.solid-nav .btn-white{background-color:#6E46AE;color:rgb(255,255'
#  b',255);border-width:0 0 1px;border-style:solid;border-color:#6E46AE;backgroun'
#  b'd-position:initial initial;background-repeat:initial initial}.navbar .navbar'
#  b'-toggle{background-image:none;border:none;background-position:initial initia'
#  b'l;background-repeat:initial initial}.navbar .navbar-toggle.search-btn-contai'
#  b'ner{margin:4px 5px 0 0;padding:8px 0 5px}.navbar .navbar-toggle i{color:#6E4'
#  b'6AE;font-size:22px;display:block;margin:0}.navbar .caret{border-top-color:rg'
#  b'ba(0,0,0,.870588);border-bottom-color:rgba(0,0,0,.870588)}.navbar li a{font-'
#  b'size:14px;color:rgba(0,0,0,.870588)}.navbar li #login-btn-employer{position:'
#  b'relative;background-color:rgb(44,122,192);right:0;text-align:center;margin:-'
#  b'2px 25px 0 0;border-top-left-radius:40px;border-top-right-radius:40px;border'
#  b'-bottom-right-radius:40px;border-bottom-left-radius:40px}.navbar li #login-b'
#  b'tn-employer a{font-weight:500;color:rgb(255,255,255);display:block;line-heig'
#  b'ht:18px;font-size:16px;padding:10px 0;width:170px;height:56px}.navbar li #lo'
#  b'gin-btn-employer a span{font-weight:400;font-size:12px}.navbar i{margin-righ'
#  b't:4px;color:rgba(255,255,255,.6)}.navbar-brand{float:left;height:50px;paddin'
#  b'g:12px 0 0 25px}.navbar-form{display:inline-block;float:none}.navbar-form in'
#  b'put,.navbar-form button{margin:0}.navbar-form .keywords,.navbar-form .locati'
#  b'on{border:1px solid rgba(255,255,255,.54902);margin-right:8px}.navbar-form .'
#  b'form-control,.navbar-form .input-group-addon{font-weight:400;background-imag'
#  b'e:none;border:none;border-top-left-radius:0;border-top-right-radius:0;border'
#  b'-bottom-right-radius:0;border-bottom-left-radius:0;box-shadow:none;color:rgb'
#  b'(255,255,255);font-size:14px;height:38px;padding:4px 8px 0;margin:0;backgrou'
#  b'nd-position:initial initial;background-repeat:initial initial}.navbar-form .'
#  b'input-group-addon i{font-size:22px}.navbar-form .form-control::-webkit-input'
#  b'-placeholder,.navbar-form .input-group-addon::-webkit-input-placeholder{colo'
#  b'r:rgb(131,83,167)}.navbar-form .form-control::-webkit-input-placeholder,.nav'
#  b'bar-form .input-group-addon::-webkit-input-placeholder{color:rgba(100,40,145'
#  b',.8)}.navbar-form .input-clear{color:rgba(100,40,145,.258824);font-size:20px'
#  b';margin:auto;position:absolute;right:6px;top:5px}.navbar-form .form-control{'
#  b'padding-left:0}.navbar-form .btn-white{position:relative;font-weight:400;fon'
#  b't-style:normal;font-variant:normal;font-size:14px;line-height:normal;font-fa'
#  b'mily:Roboto,sans-serif;height:40px;background-color:rgba(255,255,255,.247059'
#  b');border:1px solid rgba(255,255,255,.4);border-top-left-radius:0;border-top-'
#  b'right-radius:0;border-bottom-right-radius:0;border-bottom-left-radius:0;colo'
#  b'r:rgba(255,255,255,.85098);padding:5px 8px;min-width:83px;vertical-align:top'
#  b';background-position:initial initial;background-repeat:initial initial}.navb'
#  b'ar-default>.container-fluid{padding-right:0}.navbar-default .navbar-nav{marg'
#  b'in:0 0 0 25px!important}.navbar-default .navbar-nav::before,.navbar-default '
#  b'.navbar-nav::after{content:none}.nav.navbar-nav:first-child li{position:rela'
#  b'tive}.subnav{padding:0;border-width:1px 0 0;border-top-style:solid;border-to'
#  b'p-color:rgb(245,245,245);background-color:rgb(255,255,255)!important;backgro'
#  b'und-position:initial initial!important;background-repeat:initial initial!imp'
#  b'ortant}.subnav-nav>li{display:inline-block;float:none;vertical-align:top;mar'
#  b'gin-right:58px}.navbar-default .navbar-toggle .icon-bar{background-color:#6E'
#  b'46AE}.navbar-toggle{padding:12px 10px}.navbar-toggle .icon-bar{width:24px;he'
#  b'ight:3px;border-top-left-radius:0;border-top-right-radius:0;border-bottom-ri'
#  b'ght-radius:0;border-bottom-left-radius:0}.navbar-nav>li>.dropdown-menu{borde'
#  b'r:1px solid rgb(245,245,245)}.navbar-nav>li>.dropdown-menu .dropdown-menu{bo'
#  b'rder:1px solid rgb(245,245,245)}.navbar li #login-btn-employer{margin-right:'
#  b'25px}.menu{position:fixed;top:63px;left:0;width:356px;background-color:#6E46'
#  b'AE;overflow-y:auto;z-index:1999999999;background-position:initial initial;ba'
#  b'ckground-repeat:initial initial}#ml-menu-2{left:auto;right:0}.menu__wrap{pos'
#  b'ition:relative;height:100%;overflow:hidden;width:100%}.menu__level{position:'
#  b'absolute;top:0;left:0;visibility:hidden;overflow:hidden;width:100%;height:10'
#  b'0%;margin:0;padding:0;list-style-type:none}.menu__level--current{visibility:'
#  b'visible}.navbar .menu__item{display:block;width:100%}.navbar .menu__link{pos'
#  b'ition:relative;display:block;padding:10px 16px;line-height:20px;font-size:14'
#  b'px;font-weight:400;color:#6E46AE;text-decoration:none;border-bottom-width:1p'
#  b'x;border-bottom-style:solid;border-bottom-color:rgba(100,40,145,.541176);min'
#  b"-height:40px}.navbar .menu__link[data-submenu]::after{content:'\\f105'!im"
#  b'portant;font-family:FontAwesome;position:absolute;right:0;top:6px;padding:.2'
#  b'5em 1.25em!important;color:#6E46AE!important;font:normal normal normal mediu'
#  b'm/normal "FontAwesome"!important}.menu__wrap .menu__level li:last-of-type .m'
#  b'enu__link{border-top-width:1px;border-top-style:solid;border-top-color:rgba('
#  b'255,255,255,.117647);border-bottom-width:1px;border-bottom-style:solid;borde'
#  b'r-bottom-color:rgba(255,255,255,.117647)}.action{background-image:none;borde'
#  b'r:none;display:block;position:absolute;background-position:initial initial;b'
#  b'ackground-repeat:initial initial}.action--open{display:none;color:rgb(255,25'
#  b'5,255);position:fixed;z-index:1000}.navbar .action--close,.navbar #ml-menu-2'
#  b' .action--close-2{font-size:20px;top:5px;right:7px;padding:10px;color:#6E46A'
#  b'E}a.skip-main{height:1px;left:-999px;overflow:hidden;position:absolute;top:0'
#  b';width:1px;z-index:-999}@media (min-width:992px){.navbar-form{padding:0;widt'
#  b'h:532px}.navbar-form .keywords,.navbar-form .location{width:39%;margin-right'
#  b':8px}}@media (max-width:991px) and (min-width:895px){.navbar-form{width:445p'
#  b'x}}@media (min-width:768px){.navbar-default .navbar-nav{float:left}.top-subn'
#  b'av .navbar-nav>li>a{border-bottom-width:0;height:44px;line-height:20px;paddi'
#  b'ng:13px 0}.top-subnav .navbar-nav li a{background-image:none;color:rgba(0,0,'
#  b'0,.870588);font-size:14px;font-weight:400;margin:0;background-position:initi'
#  b'al initial;background-repeat:initial initial}.navbar.solid-nav .subnav-nav .'
#  b'dropdown>a{background-image:none;border-width:0 0 2px;border-style:none none'
#  b' solid;border-bottom-color:transparent;height:44px;padding:13px 0;background'
#  b'-position:initial initial;background-repeat:initial initial}.dropdown-menu{-'
#  b'webkit-background-clip:padding-box;-webkit-box-shadow:none;background-clip:p'
#  b'adding-box;background-color:rgb(255,255,255);border-top-left-radius:0;border'
#  b'-top-right-radius:0;border-bottom-right-radius:0;border-bottom-left-radius:0'
#  b';border:0 solid rgba(0,0,0,.14902);box-shadow:none;display:none;float:left;l'
#  b'eft:-25px;list-style:none;margin:0;min-width:160px;padding:12.5px 0;position'
#  b':absolute;text-align:left;top:100%;width:200px;z-index:1000}.dropdown-menu .'
#  b'dropdown-menu-sub{left:-1px;width:200px}.navbar-right .dropdown-menu{border:'
#  b'1px solid rgb(245,245,245);box-sizing:border-box;padding:6px 0 10px;top:100%'
#  b'}.navbar-right .dropdown .dropdown-menu>li>a{background-color:white;color:rg'
#  b'ba(0,0,0,.729412);display:block;font-size:14px;padding:8px 25px;white-space:'
#  b'nowrap}.dropdown .dropdown-menu>li>a{background-color:white;color:rgba(0,0,0'
#  b',.729412);display:block;font-size:14px;padding:8px 25px;white-space:normal}.'
#  b'menu{display:none}.dropdown .dropdown-menu>li>a{color:rgba(0,0,0,.870588)}.n'
#  b'avbar-right .dropdown .dropdown-menu>li>a{color:rgba(0,0,0,.870588)}.dropdow'
#  b'n-menu>li{height:auto}.navbar-nav>li>.dropdown-menu{border:0;box-shadow:rgba'
#  b'(0,0,0,.2) 0 1px 2px;left:0;margin-top:4px;padding:0}.navbar-nav>li>.dropdow'
#  b'n-menu .dropdown-menu{border:0}.navbar-nav>li>.dropdown-menu .dropdown-menu-'
#  b'sub{background-color:rgb(247,247,247);left:0;position:relative;top:0;backgro'
#  b'und-position:initial initial;background-repeat:initial initial}.navbar-nav>l'
#  b'i>.dropdown-menu .dropdown-menu-sub>li{height:0;overflow:hidden}.navbar-righ'
#  b't>li>.dropdown-menu,.navbar-right>.account-dropdown>.dropdown-menu{left:auto'
#  b';right:25px}.navbar-right .dropdown .dropdown-menu>li>a{padding:10px 12px}.d'
#  b'ropdown .dropdown-menu>li>a{padding:10px 12px}}@media (max-width:1600px) and'
#  b' (min-width:1300px){.navbar-form{width:632px}}@media (max-width:1300px) and '
#  b'(min-width:1200px){.navbar-form{width:532px}}@media (max-width:1200px) and ('
#  b'min-width:1100px){.navbar-form{width:485px}}@media (max-width:1100px){.navba'
#  b'r-form{width:451px}.navbar-form .keywords,.navbar-form .location{width:35%}.'
#  b'navbar-form .form-control,.navbar-form .input-group-addon{height:38px;font-s'
#  b'ize:14px}.navbar-form .btn-white{height:40px;font-size:14px;padding-top:6px}'
#  b'}@media (max-width:1001px){.navbar-form{width:400px;padding-left:0}.navbar-f'
#  b'orm .keywords,.navbar-form .location{border:0;width:37%;margin-right:4px}.na'
#  b'vbar-form .input-group-addon i{font-size:18px}}@media (max-width:991px){form'
#  b' .control-label{float:none;width:auto;text-align:left}form .form-actions{pad'
#  b'ding-left:0}.navbar{margin-top:0;margin-bottom:0}.navbar-form{padding-right:'
#  b'0}.navbar-default .navbar-nav{margin:0}.btn-white{padding:8px 20px}}@media ('
#  b'max-width:950px){body{padding-top:109px}.navbar-default .navbar-nav{margin:0'
#  b' 0 0 25px!important}.navbar .navbar-brand{padding:5px 15px 18px 25px}.navbar'
#  b' .navbar-right{padding-right:0}.navbar.solid-nav .navbar-main{padding-bottom'
#  b':0}.navbar-form{margin-top:2px}.navbar-form .form-control{padding:6px 12px 5'
#  b'px 0;font-size:12px;height:34px}.navbar-form .input-group-addon{padding:6px '
#  b'12px 4px;font-size:12px;height:34px}.navbar-form .btn-white{padding:6px 16px'
#  b' 5px;font-size:14px;height:36px}.navbar-form .keywords,.navbar-form .locatio'
#  b'n{width:37%;margin-right:4px}.navbar-form .location .input-group-addon{paddi'
#  b'ng-top:5px}.navbar-default .navbar-nav{margin:0}.btn-white{padding:8px 20px}'
#  b'.navbar-right #login-btn-employer{display:none}}@media (max-width:950px) and'
#  b' (min-width:767px){.navbar-form .input-clear{top:7px}}@media (max-width:767p'
#  b'x){body{padding-top:64px}.form-inline button{margin-left:0}header{padding-to'
#  b'p:0;padding-bottom:20px}.navbar{margin-top:0;margin-bottom:0;padding:0}.navb'
#  b'ar.solid-nav .navbar-main{padding-top:0}.navbar.solid-nav .navbar-text{color'
#  b':#6E46AE;font-weight:400;background-image:none;font-size:12px;padding:0;disp'
#  b'lay:block;line-height:16px;background-position:initial initial;background-re'
#  b'peat:initial initial}.logo-new-branding-g-header{width:25px;height:25px;back'
#  b'ground-size:25px;background-image:url(https://securemedia.newjobs.com/global'
#  b'/img/monster-m-logo-purple.svg)!important}.navbar .navbar-right #login-btn-e'
#  b'mployer{display:none}.navbar .navbar-collapse{overflow:hidden;border:none}.n'
#  b'avbar .navbar-collapse .navbar-form{border:none;box-shadow:none}.navbar .nav'
#  b'bar-collapse .navbar-form .top-search{text-align:left}.navbar .navbar-collap'
#  b'se .navbar-form .top-search i{width:20px}.navbar .navbar-collapse .navbar-fo'
#  b'rm .top-search.location .input-group-addon{background-image:none;background-'
#  b'position:initial initial;background-repeat:initial initial}.navbar .navbar-c'
#  b'ollapse .navbar-form .top-search.location .typeahead{background-image:none;b'
#  b'ackground-position:initial initial;background-repeat:initial initial}.navbar'
#  b' .navbar-collapse .navbar-form .top-search.keywords,.navbar .navbar-collapse'
#  b' .navbar-form .top-search.location{margin-right:0}.navbar .navbar-collapse .'
#  b'navbar-form .btn-white{height:40px;margin-top:3px;width:100%;float:left!impo'
#  b'rtant}.navbar li #login-btn-employer{position:absolute;right:0;top:-50px}.na'
#  b'vbar li #login-btn-employer a{padding:6px 20px 0;height:60px}.navbar .navbar'
#  b'-text{color:#6E46AE;font-weight:400;background-image:none;font-size:14px;lin'
#  b'e-height:20px;margin:0;padding:6px 0;background-position:initial initial;bac'
#  b'kground-repeat:initial initial}.navbar-form{width:100%;padding:4px 0 14px 6p'
#  b'x}.navbar-form .keywords,.navbar-form .location{width:100%}.navbar-form .for'
#  b'm-control,.navbar-form .input-group-addon{color:#6E46AE;font-size:14px;heigh'
#  b't:40px;line-height:24px}.navbar-form .input-group-addon i{font-size:24px;pad'
#  b'ding-top:1px}.navbar-default>.container-fluid{padding-right:15px}.navbar-def'
#  b'ault .navbar-collapse{border-color:rgb(212,214,226)}.nav{margin:0 -15px}form'
#  b' .form-control{text-align:left}}@media (max-width:550px){.navbar .navbar-rig'
#  b'ht #login-btn-employer{display:none}}@media (max-width:447px){.navbar-form{w'
#  b'idth:100%}.container-fluid{padding-left:10px;padding-right:10px}}@media (max'
#  b'-width:767px){.navbar-default .navbar-nav{display:block}.navbar-default>.con'
#  b'tainer-fluid{padding-left:15px;padding-right:15px}.navbar .navbar-collapse{b'
#  b'ackground-color:white;overflow:hidden}.navbar .navbar-toggle.search-btn-cont'
#  b'ainer{margin:4px 10px 0 0!important}.navbar-default .navbar-nav{padding-bott'
#  b'om:7px;margin:0px!important}.navbar-default .navbar-nav .dropdown .dropdown-'
#  b'menu>li>a{color:rgb(33,33,33)}.navbar-default .navbar-nav>li>a{color:rgb(33,'
#  b'33,33);font-size:16px}.navbar-default .navbar-nav>li>a>span{color:rgb(33,33,'
#  b'33);font-size:16px}.navbar-toggle{margin-right:10px}.nav>li>a{padding:10px 2'
#  b'0px}.navbar-nav .dropdown .dropdown-menu{-webkit-box-shadow:none;background-'
#  b'color:transparent;border:0;box-shadow:none;float:none;margin-top:0;position:'
#  b'static;width:auto}.navbar-nav .dropdown .dropdown-menu>li>a{padding:7px 20px'
#  b' 7px 40px}.navbar .caret{border-bottom-color:rgb(33,33,33);border-top-color:'
#  b'rgb(33,33,33)}.navbar-fixed-top .navbar-collapse{max-height:none}.navbar-hea'
#  b'der .navbar-toggle-account{background-image:none;color:#6E46AE;font-size:12p'
#  b'x;line-height:16px;margin-bottom:0;margin-right:5px;margin-top:6px;padding:6'
#  b'px 5px;position:relative;background-position:initial initial;background-repe'
#  b'at:initial initial}.navbar-toggle-account .navbar-profile-icon{background-si'
#  b'ze:23px;background-image:url(https://securemedia.newjobs.com/homepage/images'
#  b'/icons/monster-avatar.svg);display:block;height:23px;width:24px;color:transp'
#  b'arent;border:1px solid rgb(100,49,146);border-top-left-radius:50%;border-top'
#  b'-right-radius:50%;border-bottom-right-radius:50%;border-bottom-left-radius:5'
#  b'0%;background-repeat:no-repeat no-repeat}.navbar-toggle-account .logged-name'
#  b'{white-space:nowrap;max-width:53px;display:inline-block;text-overflow:ellips'
#  b'is;overflow:hidden;line-height:16px;font-size:12px;font-weight:400}.navbar-c'
#  b'ollapse{padding-left:0;padding-right:0}.navbar-form{padding:4px 20px 14px}.n'
#  b'avbar.solid-nav .keywords{border:none}.navbar.solid-nav .location{border:non'
#  b'e}.navbar.solid-nav .form-group .input-group{border:1px solid #6E46AE;border'
#  b'-top-left-radius:0;border-top-right-radius:0;border-bottom-right-radius:0;bo'
#  b'rder-bottom-left-radius:0}}@media (max-width:950px) and (min-width:768px){.n'
#  b'avbar-right .account-dropdown .dropdown-menu{right:0;left:auto}}@media (max-'
#  b'width:447px){.container-fluid{padding-left:10px;padding-right:10px}.navbar-t'
#  b'oggle{padding:12px 5px}.nav>li>a{padding:10px 16px}}@media (max-width:767px)'
#  b'{.action--open,.action--close{display:block}.menu{z-index:1999999999;top:63p'
#  b'x;width:400px;-webkit-transform:translate3d(-100%,0,0)}.menu{position:fixed;'
#  b'left:0;width:300px;background-color:rgb(255,255,255);border-width:1px 1px 1p'
#  b'x 0;border-top-style:solid;border-right-style:solid;border-bottom-style:soli'
#  b'd;border-top-color:rgba(205,205,205,.498039);border-right-color:rgba(205,205'
#  b',205,.498039);border-bottom-color:rgba(205,205,205,.498039);background-posit'
#  b'ion:initial initial;background-repeat:initial initial}#ml-menu-2.menu{-webki'
#  b't-transform:translate3d(100%,0,0)}.navbar .navbar-collapse{background-color:'
#  b'#6E46AE;background-position:initial initial;background-repeat:initial initia'
#  b'l}.navbar.solid-nav .navbar-main{padding-bottom:0}.navbar .navbar-toggle.sea'
#  b'rch-btn-container{margin-right:0}.navbar .navbar-brand{position:absolute;lef'
#  b't:0;right:0;margin:17px auto 0;width:27px;height:29px;padding:0px!important}'
#  b'.navbar-default .navbar-nav{padding-bottom:0}.navbar-toggle{padding:8px;marg'
#  b'in:16px 8px 0}.navbar-toggle.nav-trigger{float:left}.navbar-nav .dropdown .d'
#  b'ropdown-menu{padding:0}.navbar-nav .dropdown .dropdown-menu>li>a{background-'
#  b'color:rgb(120,68,159);color:rgb(255,255,255);border-top-width:1px;border-top'
#  b'-style:solid;border-top-color:rgba(255,255,255,.117647);padding:10px 16px;ba'
#  b'ckground-position:initial initial;background-repeat:initial initial}.navbar-'
#  b'nav .dropdown .dropdown-menu>li:first-child>a{border:0}.navbar-default .navb'
#  b'ar-nav .dropdown .dropdown-menu>li>a{color:rgb(255,255,255)}.navbar .navbar-'
#  b'collapse .navbar-form{padding:20px 12px 12px;margin:0}.navbar-form .form-gro'
#  b'up{margin-bottom:8px}.navbar-form .form-control{height:38px}.navbar-form .in'
#  b'put-group-addon{padding:5px 12px 3px;height:38px}.navbar-form .location .inp'
#  b'ut-group-addon{padding-bottom:2px}.navbar.solid-nav .form-group .input-group'
#  b'{border-color:transparent;background-color:rgb(255,255,255);background-posit'
#  b'ion:initial initial;background-repeat:initial initial}.navbar .navbar-collap'
#  b'se .navbar-form .btn-white{background-image:none;border:2px solid;margin-top'
#  b':4px;padding:8px 12px;background-position:initial initial;background-repeat:'
#  b'initial initial}.navbar-form .input-clear{font-size:24px!important;top:2px!i'
#  b'mportant;right:8px!important;color:rgb(215,199,227)!important}}@media (max-w'
#  b'idth:500px){.menu{width:80vw}}@media (max-width:480px){.navbar .navbar-brand'
#  b'{padding:0px!important}}@media (max-width:991px){.container{width:100%}}.nav'
#  b'bar-form .input-clear{color:rgb(204,204,204);font-family:verdana;font-weight'
#  b':500;font-size:20px;height:29px;margin:auto;position:absolute;right:7px;top:'
#  b'3px}.navbar-fixed-top .dropdown-toggle{height:auto;border:0 none}@media (max'
#  b'-width:950px) and (min-width:768px){.nav.navbar-nav.navbar-right.hidden-xs{m'
#  b'ax-width:105px}}@media (max-width:767px){#mobile-navbar-search.navbar-collap'
#  b'se .navbar-form,#mobile-navbar-search.navbar-collapse{overflow:visible}}.nav'
#  b'bar-fixed-top .top-subnav .subnav-nav{width:100%}.navbar-nav>li>.dropdown-me'
#  b'nu .dropdown-menu-sub{box-shadow:rgba(0,0,0,.2) 0 1px 2px}.dropdown .dropdow'
#  b'n-menu>li>a{white-space:normal}.dropdown-menu .dropdown-menu-sub{height:auto'
#  b';padding:0}@media (max-width:767px){.navbar-toggle-account .navbar-profile-i'
# ...
#  b'his, event)">\r\n                        <div class="flex-row">\r\n         '
#  b'                           <div class="mux-company-logo thumbnail"></div'
#  b'>\r\n                            <div class="summary">\r\n                  '
#  b'              <header class="card-header">\r\n                            '
#  b'        <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="'
#  b'JSR2CW" data-m_impr_j_cid="11" data-m_impr_j_coc="xsphhoneyx" data-m_impr_j_'
#  b'jawsid="425920656" data-m_impr_j_jobid="216472289" data-m_impr_j_jpm="1" dat'
#  b'a-m_impr_j_jpt="1" data-m_impr_j_lat="33.8358" data-m_impr_j_lid="348" data-'
#  b'm_impr_j_long="-118.3407" data-m_impr_j_occid="11892" data-m_impr_j_p="24" d'
#  b'ata-m_impr_j_postingid="2bc10bbe-5f56-4ae6-ad3f-dcc0491fdc50" data-m_impr_j_'
#  b'pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="8d1fc930-f80a-462e-a6ee-'
#  b'd8a97864b7af" href="https://job-openings.monster.com/program-planning-contro'
#  b'l-analyst-iii-torrance-ca-us-honeywell/216472289" onClick="clickJobTitle(&#3'
#  b'9;plid=348&amp;pcid=11&amp;poccid=11892&#39;,&#39;Economist&#39;,&#39;&#39;)'
#  b'; clickJobTitleSiteCat(&#39;{&quot;events.event48&quot;:&quot;true&quot;,&qu'
#  b'ot;eVar25&quot;:&quot;Program Planning \\u0026 Control Analyst III&quot;,'
#  b'&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;'
#  b',&quot;eVar26&quot;:&quot;xsphhoneyx_Honeywell&quot;,&quot;eVar31&quot;:&quo'
#  b't;Torrance_CA_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&qu'
#  b'ot;:&quot;2020-03-20T12:00&quot;,&quot;eVar53&quot;:&quot;1300093001001&quot'
#  b';,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;regular&q'
#  b'uot;}&#39;)">Program Planning &amp; Control Analyst III\r\n</a></h2>\r\n    '
#  b'                            </header>\r\n                                <'
#  b'div class="company">\r\n                                        <span clas'
#  b's="name">Honeywell</span>\r\n\r\n                                    <ul cla'
#  b'ss="list-inline">\r\n\r\n                                    </ul>\r\n    '
#  b'                            </div>\r\n                                <div'
#  b' class="location">\r\n                                        <span class='
#  b'"name">\r\nTorrance, CA\r\n</span>\r\n                                </di'
#  b'v>\r\n                            </div>\r\n                            <div'
#  b' class="meta flex-col">\r\n                                <time datetime='
#  b'"2017-05-26T12:00">1 day ago</time>\r\n                                <sp'
#  b'an data-mux="tooltip" title="Applied" class="mux-tooltip applied-only">\r'
#  b'\n                                    <i class="icon icon-applied" aria-h'
#  b'idden="true"></i>\r\n                                    <span class="sr-o'
#  b'nly">Applied</span>\r\n                                </span>\r\n          '
#  b'                      <span data-mux="tooltip" title="Saved" class="mux-tool'
#  b'tip saved-only">\r\n                                    <i class="icon ico'
#  b'n-saved" aria-hidden="true"></i>\r\n                                    <s'
#  b'pan class="sr-only">Saved</span>\r\n                                </span'
#  b'>\r\n                            </div>\r\n                        </div'
#  b'>\r\n                    </section>\r\n                    <section class="c'
#  b'ard-content "                              data-jobid="216621046"   data-pos'
#  b'tingid="a5e0995e-fb83-447e-8020-7a8925f6cd1b"   onclick="MKImpressionTrackin'
#  b'gMouseDownHijack(this, event)">\r\n                        <div class="fle'
#  b'x-row">\r\n                                    <div class="mux-company-log'
#  b'o thumbnail"></div>\r\n                            <div class="summary">\r\n'
#  b'                                <header class="card-header">\r\n          '
#  b'                          <h2 class="title"><a data-bypass="true" data-m_imp'
#  b'r_a_placement_id="JSR2CW" data-m_impr_j_cid="1" data-m_impr_j_coc="xw1464458'
#  b'79wx" data-m_impr_j_jawsid="426455680" data-m_impr_j_jobid="216621046" data-'
#  b'm_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="40.6527" data-m_im'
#  b'pr_j_lid="534" data-m_impr_j_long="-74.2601" data-m_impr_j_occid="11817" dat'
#  b'a-m_impr_j_p="25" data-m_impr_j_postingid="a5e0995e-fb83-447e-8020-7a8925f6c'
#  b'd1b" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="d2845'
#  b'330-4fa9-437b-abc2-8291c6dac1d9" href="https://job-openings.monster.com/staf'
#  b'f-accountant-roselle-nj-us-pamarco-global-graphics/216621046" onClick="click'
#  b'JobTitle(&#39;plid=534&amp;pcid=1&amp;poccid=11817&#39;,&#39;Economist&#39;,'
#  b'&#39;&#39;); clickJobTitleSiteCat(&#39;{&quot;events.event48&quot;:&quot;tru'
#  b'e&quot;,&quot;eVar25&quot;:&quot;Staff Accountant&quot;,&quot;eVar66&quot;:&'
#  b'quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:'
#  b'&quot;xw146445879wx_Pamarco Global Graphics&quot;,&quot;eVar31&quot;:&quot;R'
#  b'oselle_NJ_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:'
#  b'&quot;2020-03-19T12:00&quot;,&quot;eVar53&quot;:&quot;1300101001001&quot;,&q'
#  b'uot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;regular&quot;'
#  b'}&#39;)">Staff Accountant\r\n</a></h2>\r\n                                </'
#  b'header>\r\n                                <div class="company">\r\n        '
#  b'                                <span class="name">Pamarco Global Graphics</'
#  b'span>\r\n\r\n                                    <ul class="list-inline"'
#  b'>\r\n\r\n                                    </ul>\r\n                    '
#  b'            </div>\r\n                                <div class="location'
#  b'">\r\n                                        <span class="name">\r\nRoselle'
#  b', NJ\r\n</span>\r\n                                </div>\r\n             '
#  b'               </div>\r\n                            <div class="meta flex'
#  b'-col">\r\n                                <time datetime="2017-05-26T12:00'
#  b'">2 days ago</time>\r\n                                <span data-mux="too'
#  b'ltip" title="Applied" class="mux-tooltip applied-only">\r\n               '
#  b'                     <i class="icon icon-applied" aria-hidden="true"></i'
#  b'>\r\n                                    <span class="sr-only">Applied</sp'
#  b'an>\r\n                                </span>\r\n                          '
#  b'      <span data-mux="tooltip" title="Saved" class="mux-tooltip saved-only">'
#  b'\r\n                                    <i class="icon icon-saved" aria-hi'
#  b'dden="true"></i>\r\n                                    <span class="sr-on'
#  b'ly">Saved</span>\r\n                                </span>\r\n             '
#  b'               </div>\r\n                        </div>\r\n                 '
#  b'   </section>\r\n                    <section class="card-content "       '
#  b'                       data-jobid="216812628"   data-postingid="486cdfe5-11f'
#  b'a-4c06-9822-78558b69f437"   onclick="MKImpressionTrackingMouseDownHijack(thi'
#  b's, event)">\r\n                        <div class="flex-row">\r\n           '
#  b'                         <div class="mux-company-logo thumbnail"></div>\r'
#  b'\n                            <div class="summary">\r\n                    '
#  b'            <header class="card-header">\r\n                              '
#  b'      <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JS'
#  b'R2CW" data-m_impr_j_cid="5623" data-m_impr_j_coc="xlnpmediax" data-m_impr_j_'
#  b'jawsid="427364927" data-m_impr_j_jobid="216812628" data-m_impr_j_jpm="1" dat'
#  b'a-m_impr_j_jpt="1" data-m_impr_j_lat="40.0115" data-m_impr_j_lid="703" data-'
#  b'm_impr_j_long="-76.3553" data-m_impr_j_occid="11781" data-m_impr_j_p="26" da'
#  b'ta-m_impr_j_postingid="486cdfe5-11fa-4c06-9822-78558b69f437" data-m_impr_j_p'
#  b'vc="monster" data-m_impr_s_t="t" data-m_impr_uuid="a553507a-ccae-4a2a-b8d6-4'
#  b'df20affd3ae" href="https://job-openings.monster.com/business-editor-lancaste'
#  b'r-pa-us-lnp-media-group/216812628" onClick="clickJobTitle(&#39;plid=703&amp;'
#  b'pcid=5623&amp;poccid=11781&#39;,&#39;Economist&#39;,&#39;&#39;); clickJobTit'
#  b'leSiteCat(&#39;{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quo'
#  b't;:&quot;Business Editor&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;'
#  b'eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xlnpmediax_LNP Medi'
#  b'a Group&quot;,&quot;eVar31&quot;:&quot;Lancaster_PA_&quot;,&quot;prop22&quot'
#  b';:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-03-19T12:00&quot;,&quot'
#  b';eVar53&quot;:&quot;2700439001001&quot;,&quot;eVar50&quot;:&quot;Duration&qu'
#  b'ot;,&quot;eVar74&quot;:&quot;regular&quot;}&#39;)">Business Editor\r\n</a>'
#  b'</h2>\r\n                                </header>\r\n                      '
#  b'          <div class="company">\r\n                                       '
#  b' <span class="name">LNP Media Group</span>\r\n\r\n                          '
#  b'          <ul class="list-inline">\r\n\r\n                                  '
#  b'  </ul>\r\n                                </div>\r\n                       '
#  b'         <div class="location">\r\n                                       '
#  b' <span class="name">\r\nLancaster, PA\r\n</span>\r\n                      '
#  b'          </div>\r\n                            </div>\r\n                  '
#  b'          <div class="meta flex-col">\r\n                                <'
#  b'time datetime="2017-05-26T12:00">2 days ago</time>\r\n                    '
#  b'            <span data-mux="tooltip" title="Applied" class="mux-tooltip appl'
#  b'ied-only">\r\n                                    <i class="icon icon-appl'
#  b'ied" aria-hidden="true"></i>\r\n                                    <span '
#  b'class="sr-only">Applied</span>\r\n                                </span>\r'
#  b'\n                                <span data-mux="tooltip" title="Saved" '
#  b'class="mux-tooltip saved-only">\r\n                                    <i '
#  b'class="icon icon-saved" aria-hidden="true"></i>\r\n                       '
#  b'             <span class="sr-only">Saved</span>\r\n                       '
#  b'         </span>\r\n                            </div>\r\n                  '
#  b'      </div>\r\n                    </section>\r\n    </div>\r\n\r\n    <a c'
#  b'lass="mux-btn btn-secondary load-more-btn " id="loadMoreJobs" data-action="f'
#  b'etch" role="button" href="https://www.monster.com/jobs/search/?page=2">Load '
#  b'more jobs</a>\r\n    <a class="mux-btn btn-secondary no-more-jobs-btn disa'
#  b'bled " style="display:none" id="noMoreResults" role="button">No More Results'
#  b'</a>\r\n</div>\r\n\r\n    \r\n                        </div>\r\n          '
#  b'          </div>\r\n                </div>\r\n                <div class="co'
#  b'l-md-8 detail-only">\r\n                    <div id="ContentContainer" cla'
#  b'ss="mux-custom-scroll mux-content-container" data-mux="customScroll" data-ex'
#  b'tend="right">\r\n                        <div id="ContentScrollable" class'
#  b'="scrollable">\r\n                            \r\n\r\n                    '
#  b'        <div\r\n                                id="JobPreview"\r\n         '
#  b'                       class="mux-job-preview"\r\n                        '
#  b'        data-mux="jobPreview"\r\n                                data-clou'
#  b'd-api-uri="//logs2.jobs.com"\r\n                                data-conte'
#  b'nt-url="//job-openings.monster.com/v2/job/pure-json-view"\r\n             '
#  b'                   data-messages-url="https://coda.newjobs.com/Assets/MUX/Ja'
#  b'JobViewCloud/2020.02.0.746/msgset;MONS/app.jv30.ids"\r\n                  '
#  b'              data-content-template="job-preview-template"\r\n            '
#  b'                    data-content-placeholder="job-preview-placeholder-templa'
#  b'te"\r\n                                data-error-template="job-preview-er'
#  b'ror-template"\r\n                                data-offset-scroll="100"\r'
#  b'\n                                data-apply-btn="#PrimaryJobApply"\r\n    '
#  b'                            data-email-btn="#emailFriendOpen"\r\n         '
#  b'                   ></div>\r\n                            <div class="mux-'
#  b'mobile-navigation" data-mux="mobileNavigation" data-source="#SearchResults">'
#  b'</div>\r\n                            \r\n\r\n                            '
#  b'<script type="text/x-placeholder" id="FooterCustomScroll"></script>\r\n   '
#  b'                     </div>\r\n                    </div>\r\n               '
#  b' </div>\r\n            </div>\r\n            <div class="dimmed-only"></div>'
#  b'\r\n        </main>\r\n        \r\n    \r\n<footer id="PageFooter" role="con'
#  b'tentinfo" class="mux-page-footer" data-mux="cardResponsive" data-target="#Fo'
#  b'oterCustomScroll" data-breakpoints="md,lg">\r\n        <div class="footer-'
#  b'content">\r\n            <a href="https://www.monster.com/" class="home"><'
#  b'i class="monster-logo-abbr"></i><span class="sr-only">CareerOne</span></'
#  b'a>\r\n            <div class="legal-nav">\r\n                <small class="c'
#  b'opyright">Copyright \xc2\xa9 2020 | Monster Worldwide </small>\r\n          '
#  b'      <small class="patents">U.S. Patents No. 7,599,930 B1; 7,827,125 and 7,'
#  b'836,060</small>\r\n                <small class="affiliates"></small>\r\n   '
#  b'         </div>\r\n            <div class="mux-a11y-switch">\r\n            '
#  b'    <input type="checkbox" id="a11ySwitch" />\r\n                <label fo'
#  b'r="a11ySwitch" class="toggle" data-mux="a11ySwitch" data-src="https://coda.n'
#  b'ewjobs.com/Assets/MUX/CoreLpf20/2020.01.0.172/css/app.lpf20.a11y.css https:/'
#  b'/coda.newjobs.com/Assets/MUX/JaJobViewCloud/2020.02.0.746/css/app.js30.a11y.'
#  b'css" data-text="Standard color version">\r\n                    <i class="'
#  b'icon icon-contrast"></i>\r\n                    <span class="label">High c'
#  b'ontrast version</span>\r\n                </label>\r\n            </div>'
#  b'\r\n        </div>\r\n</footer>\r\n\r\n\r\n    </div>\r\n    \r\n\r\n\r\n\r'
#  b'\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r'
#  b'\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n    <div class="hide">\r\n\r\n    \r\n<sc'
#  b'ript id="mww_icp_tracking" type="text/javascript" async="true" src="//media.'
#  b'newjobs.com/mm/rainbow/tracking/scripts/Icp/IdentityTracking.js?v=4554511"><'
#  b'/script>\r\n\r\n        \r\n<div style="display:none;"></div>\r\n       '
#  b' \r\n\r\n\r\n        \r\n\r\n\r\n\r\n    </div>\r\n    <script type="text/ja'
#  b'vascript">\r\n        \r\n            var filename = \'https://coda.newjo'
#  b"bs.com/Assets/MUX/JaJobViewCloud/2020.02.0.746/js/app.js30.bundle.js'.split("
#  b"'/').pop();\r\n            const asyncScriptsNodeList = document.querySele"
#  b'ctorAll("script[src*=\'"+filename+"\']");\r\n            var asyncScripts = '
#  b'Array.prototype.slice.call(asyncScriptsNodeList);\r\n            asyncScri'
#  b'pts.forEach(function (sc) {\r\n                sc.onload = function () {\r\n'
#  b'                    \r\n                    (function ($, d) {\r\n          '
#  b'              readyQ.forEach(function (f) {\r\n                           '
#  b' $(f);\r\n                        });\r\n                        bindReadyQ.'
#  b'forEach(function (f) {\r\n                            $(d).bind("ready", f'
#  b');\r\n                        });\r\n                    })(jQuery, document'
#  b');\r\n                    (function ($, w) {\r\n                        load'
#  b'Q.forEach(function (f) {\r\n                            $(w).load(f);\r\n   '
#  b'                     });\r\n                        bindLoadQ.forEach(func'
#  b'tion (f) {\r\n                            $(w).bind("load", f);\r\n         '
#  b'               });\r\n                    })(jQuery, window);\r\n           '
#  b'     }\r\n            });\r\n    </script>\r\n</body>\r\n</html>\r\n')

# %% [markdown]
# We have our html content. It's messy : let's turn to the **cleaning** and **parsing** parts.

# %% [markdown]
# ### Clean and analyze the HTML

# %% [markdown]
# The package `BeautifulSoup` in Python is exactly here for that. You give its functions the HTML content, it returns readable information. Let's create a `BeautifulSoup` object, indicating the function what language to parse in second argument.

# %%
soup = BeautifulSoup(page.content, 'html.parser') #parse the HTML with BeautifulSoup/

# %% [markdown]
# There are two ways to retrieve elements from that objects. In an `HTML`, each element has an `id`. You can hence pick an element by passing the id to the function that does that. Here for example, the element that contains all the listings is named `ResultsContainer`.

# %%
results = soup.find(id='ResultsContainer') #extract one element

# %%
print(results.prettify())
# Out:
# <div class="mux-custom-scroll" data-extend="left" data-mux="customScroll" data-target="html" id="ResultsContainer">
#  <div class="scrollable" id="ResultsScrollable">
#   <script type="application/ld+json">
#    {"@context":"https://schema.org","@type":"ItemList","mainEntityOfPage":{
#             "@type":"CollectionPage","@id":"https://www.monster.com/jobs/search/?q=Economist&amp;where=USA"
#             }
#             ,"itemListElement":[
#
#                  {"@type":"ListItem","position":1,"url":"https://job-openings.monster.com/transportation-economist-mill-creek-building-odot-or-us-oregon-department-of-transportation/216739002"}
#                     ,
#                  {"@type":"ListItem","position":2,"url":""}
#                     ,
#                  {"@type":"ListItem","position":3,"url":"https://job-openings.monster.com/senior-economist-albany-ny-us-nys-office-of-the-state-comptroller/216493284"}
#                     ,
#                  {"@type":"ListItem","position":4,"url":"https://job-openings.monster.com/sr-transportation-economist-sr-business-intelligence-planner-washington-dc-us-washington-metropolitan-area-transit-authority/216685632"}
#                     ,
#                  {"@type":"ListItem","position":5,"url":"https://job-openings.monster.com/international-economist-philadelphia-pa-us-university-of-pennsylvania/216313117"}
#                     ,
#                  {"@type":"ListItem","position":6,"url":"https://job-openings.monster.com/economist-rensselaer-ny-us-nyiso/216090939"}
#                     ,
#                  {"@type":"ListItem","position":7,"url":"https://job-openings.monster.com/senior-equity-research-associate-finance-economics-cleveland-oh-us-cybercoders/216717155"}
#                     ,
#                  {"@type":"ListItem","position":8,"url":""}
#                     ,
#                  {"@type":"ListItem","position":9,"url":"https://job-openings.monster.com/economics-education-sme-atkinson-nh-us-gex-inc/215090143"}
#                     ,
#                  {"@type":"ListItem","position":10,"url":"https://job-openings.monster.com/economic-development-director-mount-snow-vt-us-town-of-dover/216859301"}
#                     ,
#                  {"@type":"ListItem","position":11,"url":"https://job-openings.monster.com/project-manager-office-of-economic-development-las-vegas-nv-us-university-of-nevada-las-vegas/216184337"}
#                     ,
#                  {"@type":"ListItem","position":12,"url":"https://job-openings.monster.com/vp-real-estate-technology-san-antonio-tx-us-penfed-credit-union/5941e56d-0985-4b4f-b42e-c8ed825cf86b"}
#                     ,
#                  {"@type":"ListItem","position":13,"url":"https://job-openings.monster.com/economist-seattle-wa-us-amazon-corporate-llc/216838335"}
#                     ,
#                  {"@type":"ListItem","position":14,"url":"https://job-openings.monster.com/director-product-marketing-white-plains-ny-us-new-york-power-authority/216401612"}
#                     ,
#                  {"@type":"ListItem","position":15,"url":"https://job-openings.monster.com/sales-planning-analytics-dearborn-mi-us-advantage-resourcing/216803807"}
#                     ,
#                  {"@type":"ListItem","position":16,"url":"https://job-openings.monster.com/loss-analyst-detroit-mi-us-quicken-loans/c8f88771-a8fa-49c1-b6da-bb396d78f9ac"}
#                     ,
#                  {"@type":"ListItem","position":17,"url":"https://job-openings.monster.com/global-forecasting-economic-planning-manager-redmond-wa-us-terex-corporation/216170327"}
#                     ,
#                  {"@type":"ListItem","position":18,"url":"https://job-openings.monster.com/postdoctoral-research-scholar-raleigh-nc-us-north-carolina-state-univ/216321892"}
#                     ,
#                  {"@type":"ListItem","position":19,"url":""}
#                     ,
#                  {"@type":"ListItem","position":20,"url":"https://job-openings.monster.com/senior-financial-analyst-phoenix-az-us-collabera/216545342"}
#                     ,
#                  {"@type":"ListItem","position":21,"url":"https://job-openings.monster.com/lead-data-scientist-broomfield-co-us-centurylink/66dd6c61-5da4-4eb5-992a-2fbf2021a512"}
#                     ,
#                  {"@type":"ListItem","position":22,"url":"https://job-openings.monster.com/associate-manager-commercial-intelligence-pr-us-hersheycareers/216843389"}
#                     ,
#                  {"@type":"ListItem","position":23,"url":"https://job-openings.monster.com/senior-analyst-control-testing-services-arlington-va-us-e-trade/216832845"}
#                     ,
#                  {"@type":"ListItem","position":24,"url":"https://job-openings.monster.com/model-risk-director-quant-model-validation-jersey-city-nj-us-my-hr-supplier/216852703"}
#                     ,
#                  {"@type":"ListItem","position":25,"url":"https://job-openings.monster.com/tax-specialist-bolingbrook-il-us-beko-us-inc/216131754"}
#                     ,
#                  {"@type":"ListItem","position":26,"url":"https://job-openings.monster.com/project-program-control-analyst-san-diego-ca-us-cobham/216841798"}
#                     ,
#                  {"@type":"ListItem","position":27,"url":"https://job-openings.monster.com/program-planning-control-analyst-iii-torrance-ca-us-honeywell/216472289"}
#                     ,
#                  {"@type":"ListItem","position":28,"url":"https://job-openings.monster.com/staff-accountant-roselle-nj-us-pamarco-global-graphics/216621046"}
#                     ,
#                  {"@type":"ListItem","position":29,"url":"https://job-openings.monster.com/business-editor-lancaster-pa-us-lnp-media-group/216812628"}
#             ]}
#   </script>
#   <script>
#    function lockScroll() {
#             var lockX = window.scrollX;
#             var lockY = window.scrollY;
#
#             function lockIt() {
#                 window.scrollTo(lockX, lockY);
#                 return false;
#             }
#
#             window.addEventListener("scroll", lockIt, false);
#             return {
#                 stop: function () {
#                     window.removeEventListener("scroll", lockIt, false);
#                 }
#             }
#         }
#         window.addEventListener("load", function () {
#             $('#ResultsScrollable').bind("scroll", function () {
#                 if ($(this).scrollTop() + $(this).innerHeight() >= $(this)[0].scrollHeight) {
#                     var locker = lockScroll();
#                     var loadBtn = document.getElementById('loadMoreJobs');
#                     if (loadBtn) loadBtn.click();
#                     locker.stop();
#                 }
#             });
#         });
#   </script>
#   <style>
#    #loadMoreJobs {
#             display: none;
#         }
#   </style>
#   <div class="mux-apas-ads" data-ads='[{"sizes":[1,1],"placementId":14162549,"id":"bad1"},{"sizes":[1,1],"placementId":14343737,"id":"bad2"},{"sizes":[728,90],"placementId":14343738,"id":"bad3"}]' data-config='{"targeting":{"Site":"United States","mURL":"https%3a%2f%2fwww.monster.com%2fjobs%2fsearch%2f%3fq%3dEconomist%26where%3dUSA","Page":"Job Search Results","mesco":[1300093001001,5301072001001]},"member":3525}' data-mux="apasAds">
#   </div>
#   <div class="mux-search-results" data-content-target="#JobPreview" data-emulated-click-attr="coretrackclickauto" data-is-dynamic="true" data-jhash-size="10" data-jhash-url="https://www.monster.com/jobs/search/jhpagination?q=Economist&amp;where=USA" data-jv-non-job-content="-1" data-mux="searchResults" data-results-max="250" data-results-page="1" data-results-per-page="25" data-results-placeholder="job-item-placeholder-template" data-results-target="#SearchResults" data-results-template="job-item-template" data-results-total="250" data-results-url="https://www.monster.com/jobs/search/pagination/?q=Economist&amp;where=USA&amp;isDynamicPage=true&amp;isMKPagination=true" data-total-search-results="21127">
#    <div class="mux-card mux-job-card" id="SearchResults">
#     <section class="card-content" data-jobid="216739002" data-postingid="f3991871-0cf7-4a34-bffc-9674024247db" onclick="MKImpressionTrackingMouseDownHijack(this, event)">
#      <div class="flex-row">
#       <div class="mux-company-logo thumbnail">
#       </div>
#       <div class="summary">
#        <header class="card-header">
#         <h2 class="title">
#          <a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="11" data-m_impr_j_coc="xw301558987wx" data-m_impr_j_jawsid="427022700" data-m_impr_j_jobid="216739002" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="0" data-m_impr_j_lid="573" data-m_impr_j_long="0" data-m_impr_j_occid="11892" data-m_impr_j_p="1" data-m_impr_j_postingid="f3991871-0cf7-4a34-bffc-9674024247db" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="f97f7172-f9be-4241-820d-3ce00786b919" href="https://job-openings.monster.com/transportation-economist-mill-creek-building-odot-or-us-oregon-department-of-transportation/216739002" onclick="clickJobTitle('plid=573&amp;pcid=11&amp;poccid=11892','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Transportation Economist&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xw301558987wx_Oregon Department of Transportation&quot;,&quot;eVar31&quot;:&quot;Mill Creek Building - ODOT_OR_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-03-16T12:00&quot;,&quot;eVar53&quot;:&quot;5301072001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">
#           Transportation Economist
#          </a>
#         </h2>
#        </header>
#        <div class="company">
#         <span class="name">
#          Oregon Department of Transportation
#         </span>
#         <ul class="list-inline">
#         </ul>
#        </div>
#        <div class="location">
#         <span class="name">
#          Mill Creek Building - ODOT, OR
#         </span>
#        </div>
#       </div>
#       <div class="meta flex-col">
#        <time datetime="2017-05-26T12:00">
#         5 days ago
#        </time>
#        <span class="mux-tooltip applied-only" data-mux="tooltip" title="Applied">
#         <i aria-hidden="true" class="icon icon-applied">
#         </i>
#         <span class="sr-only">
#          Applied
#         </span>
#        </span>
#        <span class="mux-tooltip saved-only" data-mux="tooltip" title="Saved">
#         <i aria-hidden="true" class="icon icon-saved">
#         </i>
#         <span class="sr-only">
#          Saved
#         </span>
#        </span>
#       </div>
#      </div>
#     </section>
#     <section class="card-content apas-ad" data-mux="searchResultsAds" style="display:none">
#      <div id="bad1">
#      </div>
#     </section>
#     <section class="card-content" data-jobid="216493284" data-postingid="9f860997-6841-4cc5-942d-7856190cc6cb" onclick="MKImpressionTrackingMouseDownHijack(this, event)">
#      <div class="flex-row">
#       <div class="mux-company-logo thumbnail">
#       </div>
#       <div class="summary">
#        <header class="card-header">
#         <h2 class="title">
#          <a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="559" data-m_impr_j_coc="xtime_nyoscx" data-m_impr_j_jawsid="425967836" data-m_impr_j_jobid="216493284" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="42.6525" data-m_impr_j_lid="544" data-m_impr_j_long="-73.7563" data-m_impr_j_occid="11866" data-m_impr_j_p="2" data-m_impr_j_postingid="9f860997-6841-4cc5-942d-7856190cc6cb" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="75217ea2-2cef-4480-8abe-de16764851b7" href="https://job-openings.monster.com/senior-economist-albany-ny-us-nys-office-of-the-state-comptroller/216493284" onclick="clickJobTitle('plid=544&amp;pcid=559&amp;poccid=11866','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Senior Economist&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xtime_nyoscx_NYS Office of the State Comptroller&quot;,&quot;eVar31&quot;:&quot;Albany_NY_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-03-20T12:00&quot;,&quot;eVar53&quot;:&quot;1900269001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">
#           Senior Economist
#          </a>
#         </h2>
#        </header>
#        <div class="company">
#         <span class="name">
#          NYS Office of the State Comptroller
#         </span>
#         <ul class="list-inline">
#         </ul>
#        </div>
#        <div class="location">
#         <span class="name">
#          Albany, NY
#         </span>
#        </div>
#       </div>
#       <div class="meta flex-col">
#        <time datetime="2017-05-26T12:00">
#         1 day ago
#        </time>
#        <span class="mux-tooltip applied-only" data-mux="tooltip" title="Applied">
#         <i aria-hidden="true" class="icon icon-applied">
#         </i>
#         <span class="sr-only">
#          Applied
#         </span>
#        </span>
#        <span class="mux-tooltip saved-only" data-mux="tooltip" title="Saved">
#         <i aria-hidden="true" class="icon icon-saved">
#         </i>
#         <span class="sr-only">
#          Saved
#         </span>
#        </span>
#       </div>
#      </div>
#     </section>
#     <section class="card-content" data-jobid="216685632" data-postingid="b69a8d9b-d82f-4678-a0fb-4c048114a47d" onclick="MKImpressionTrackingMouseDownHijack(this, event)">
#      <div class="flex-row">
#       <div class="mux-company-logo thumbnail is-loaded">
#        <img alt="Washington Metropolitan Area Transit Authority" src="//media.newjobs.com/mm/xwmatax/nb/MLogo.png"/>
#       </div>
#       <div class="summary">
#        <header class="card-header">
#         <h2 class="title">
#          <a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="9008" data-m_impr_j_coc="xwmatax" data-m_impr_j_jawsid="426718079" data-m_impr_j_jobid="216685632" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="38.8951" data-m_impr_j_lid="371" data-m_impr_j_long="-77.0364" data-m_impr_j_occid="11910" data-m_impr_j_p="3" data-m_impr_j_postingid="b69a8d9b-d82f-4678-a0fb-4c048114a47d" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="aea80468-3817-4e4e-82a3-7fdaebbf603a" href="https://job-openings.monster.com/sr-transportation-economist-sr-business-intelligence-planner-washington-dc-us-washington-metropolitan-area-transit-authority/216685632" onclick="clickJobTitle('plid=371&amp;pcid=9008&amp;poccid=11910','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Sr. Transportation Economist (Sr. Business Intelligence Planner)&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xwmatax_Washington Metropolitan Area Transit Authority&quot;,&quot;eVar31&quot;:&quot;Washington_DC_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-03-13T12:00&quot;,&quot;eVar53&quot;:&quot;1500144001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;logo&quot;}')">
#           Sr. Transportation Economist (Sr. Business Intelligence Planner)
#          </a>
#         </h2>
#        </header>
#        <div class="company">
#         <span class="name">
#          Washington Metropolitan Area Transit Authority
#         </span>
#         <ul class="list-inline">
#         </ul>
#        </div>
#        <div class="location">
#         <span class="name">
#          Washington, DC
#         </span>
#        </div>
#       </div>
#       <div class="meta flex-col">
#        <time datetime="2017-05-26T12:00">
#         8 days ago
#        </time>
#        <span class="mux-tooltip applied-only" data-mux="tooltip" title="Applied">
#         <i aria-hidden="true" class="icon icon-applied">
#         </i>
#         <span class="sr-only">
#          Applied
#         </span>
#        </span>
#        <span class="mux-tooltip saved-only" data-mux="tooltip" title="Saved">
#         <i aria-hidden="true" class="icon icon-saved">
#         </i>
#         <span class="sr-only">
#          Saved
#         </span>
#        </span>
#       </div>
#      </div>
#     </section>
#     <section class="card-content" data-jobid="216313117" data-postingid="ae90f5f5-6ad8-4397-b27c-f6acd1b214b6" onclick="MKImpressionTrackingMouseDownHijack(this, event)">
#      <div class="flex-row">
#       <div class="mux-company-logo thumbnail">
#       </div>
#       <div class="summary">
#        <header class="card-header">
#         <h2 class="title">
#          <a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="11" data-m_impr_j_coc="xpn600252615_pcarlsx" data-m_impr_j_jawsid="424586741" data-m_impr_j_jobid="216313117" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="39.9616" data-m_impr_j_lid="585" data-m_impr_j_long="-75.1995" data-m_impr_j_occid="11892" data-m_impr_j_p="4" data-m_impr_j_postingid="ae90f5f5-6ad8-4397-b27c-f6acd1b214b6" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="af0c72cc-306d-463a-affd-275de63a9889" href="https://job-openings.monster.com/international-economist-philadelphia-pa-us-university-of-pennsylvania/216313117" onclick="clickJobTitle('plid=585&amp;pcid=11&amp;poccid=11892','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;INTERNATIONAL ECONOMIST&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xpn600252615_pcarlsx_UNIVERSITY OF PENNSYLVANIA&quot;,&quot;eVar31&quot;:&quot;Philadelphia_PA_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-03-01T12:00&quot;,&quot;eVar53&quot;:&quot;1900269001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">
#           INTERNATIONAL ECONOMIST
#          </a>
#         </h2>
#        </header>
#        <div class="company">
#         <span class="name">
#          UNIVERSITY OF PENNSYLVANIA
#         </span>
#         <ul class="list-inline">
#         </ul>
#        </div>
#        <div class="location">
#         <span class="name">
#          Philadelphia, PA
#         </span>
#        </div>
#       </div>
#       <div class="meta flex-col">
#        <time datetime="2017-05-26T12:00">
#         20 days ago
#        </time>
#        <span class="mux-tooltip applied-only" data-mux="tooltip" title="Applied">
#         <i aria-hidden="true" class="icon icon-applied">
#         </i>
#         <span class="sr-only">
#          Applied
#         </span>
#        </span>
#        <span class="mux-tooltip saved-only" data-mux="tooltip" title="Saved">
#         <i aria-hidden="true" class="icon icon-saved">
#         </i>
#         <span class="sr-only">
#          Saved
#         </span>
#        </span>
#       </div>
#      </div>
#     </section>
#     <section class="card-content is-bold" data-jobid="216090939" data-postingid="c0d7c8d8-afb0-472e-acdf-1be8b7058344" onclick="MKImpressionTrackingMouseDownHijack(this, event)">
#      <div class="flex-row">
#       <div class="mux-company-logo thumbnail is-loaded">
#        <img alt="NYISO" src="https://coda.newjobs.com/api/imagesproxy/ms/mm/xnyisox/cp/new-logo.png"/>
#       </div>
#       <div class="summary">
#        <header class="card-header">
#         <h2 class="title">
#          <a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="3561" data-m_impr_j_coc="xnyisox" data-m_impr_j_jawsid="423237675" data-m_impr_j_jobid="216090939" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="42.6273" data-m_impr_j_lid="544" data-m_impr_j_long="-73.7089" data-m_impr_j_occid="11895" data-m_impr_j_p="5" data-m_impr_j_postingid="c0d7c8d8-afb0-472e-acdf-1be8b7058344" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="4c0862fb-29cc-4e8c-a3c8-d7692b4f5174" href="https://job-openings.monster.com/economist-rensselaer-ny-us-nyiso/216090939" onclick="clickJobTitle('plid=544&amp;pcid=3561&amp;poccid=11895','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Economist&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xnyisox_NYISO&quot;,&quot;eVar31&quot;:&quot;Rensselaer_NY_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-03-20T12:00&quot;,&quot;eVar53&quot;:&quot;1900269001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;bolded-logo&quot;}')">
#           Economist
#          </a>
#         </h2>
#        </header>
#        <div class="company">
#         <span class="name">
#          NYISO
#         </span>
#         <ul class="list-inline">
#         </ul>
#        </div>
#        <div class="location">
#         <span class="name">
#          Rensselaer, NY
#         </span>
#        </div>
#       </div>
#       <div class="meta flex-col">
#        <time datetime="2017-05-26T12:00">
#         1 day ago
#        </time>
#        <span class="mux-tooltip applied-only" data-mux="tooltip" title="Applied">
#         <i aria-hidden="true" class="icon icon-applied">
#         </i>
#         <span class="sr-only">
#          Applied
#         </span>
#        </span>
#        <span class="mux-tooltip saved-only" data-mux="tooltip" title="Saved">
#         <i aria-hidden="true" class="icon icon-saved">
#         </i>
#         <span class="sr-only">
#          Saved
#         </span>
#        </span>
#       </div>
#      </div>
#     </section>
#     <section class="card-content" data-jobid="216717155" data-postingid="8f5102a5-a7c6-4df7-b3ea-20618e285238" onclick="MKImpressionTrackingMouseDownHijack(this, event)">
#      <div class="flex-row">
#       <div class="mux-company-logo thumbnail is-loaded">
#        <img alt="CyberCoders" src="https://media.newjobs.com/clu/xcyb/xcyberc3x/branding/6344/CyberCoders-logo.jpg"/>
#       </div>
#       <div class="summary">
#        <header class="card-header">
#         <h2 class="title">
#          <a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="1" data-m_impr_j_coc="xcyberc3x" data-m_impr_j_jawsid="426970177" data-m_impr_j_jobid="216717155" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="41.4995" data-m_impr_j_lid="560" data-m_impr_j_long="-81.6955" data-m_impr_j_occid="11760" data-m_impr_j_p="6" data-m_impr_j_postingid="8f5102a5-a7c6-4df7-b3ea-20618e285238" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="a8303f11-332e-4e8f-b2f5-3eca1d50ea91" href="https://job-openings.monster.com/senior-equity-research-associate-finance-economics-cleveland-oh-us-cybercoders/216717155" onclick="clickJobTitle('plid=560&amp;pcid=1&amp;poccid=11760','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Senior Equity Research Associate - Finance, Economics&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xcyberc3x_CyberCoders&quot;,&quot;eVar31&quot;:&quot;Cleveland_OH_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-03-16T12:00&quot;,&quot;eVar53&quot;:&quot;1900305001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;logo&quot;}')">
#           Senior Equity Research Associate - Finance, Economics
#          </a>
#         </h2>
#        </header>
#        <div class="company">
#         <span class="name">
#          CyberCoders
#         </span>
#         <ul class="list-inline">
#         </ul>
#        </div>
#        <div class="location">
#         <span class="name">
#          Cleveland, OH
#         </span>
#        </div>
#       </div>
#       <div class="meta flex-col">
#        <time datetime="2017-05-26T12:00">
#         5 days ago
#        </time>
#        <span class="mux-tooltip applied-only" data-mux="tooltip" title="Applied">
#         <i aria-hidden="true" class="icon icon-applied">
#         </i>
#         <span class="sr-only">
#          Applied
#         </span>
#        </span>
#        <span class="mux-tooltip saved-only" data-mux="tooltip" title="Saved">
#         <i aria-hidden="true" class="icon icon-saved">
#         </i>
#         <span class="sr-only">
#          Saved
#         </span>
#        </span>
#       </div>
#      </div>
#     </section>
#     <section class="card-content apas-ad" data-mux="searchResultsAds" style="display:none">
#      <div id="bad2">
#      </div>
#     </section>
#     <section class="card-content" data-jobid="215090143" data-postingid="462c770e-e8f2-46ba-8b40-55ddfeb10888" onclick="MKImpressionTrackingMouseDownHijack(this, event)">
#      <div class="flex-row">
#       <div class="mux-company-logo thumbnail is-loaded">
#        <img alt="GEX, Inc." src="https://coda.newjobs.com/api/imagesproxy/ms/clu/xw28/xw288169336wx/branding/162900/GEX-Inc-logo.jpg"/>
#       </div>
#       <div class="summary">
#        <header class="card-header">
#         <h2 class="title">
#          <a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="3" data-m_impr_j_coc="xw288169336wx" data-m_impr_j_jawsid="417720813" data-m_impr_j_jobid="215090143" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="42.8379" data-m_impr_j_lid="530" data-m_impr_j_long="-71.1618" data-m_impr_j_occid="11915" data-m_impr_j_p="7" data-m_impr_j_postingid="462c770e-e8f2-46ba-8b40-55ddfeb10888" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="0b0de47b-346c-42b2-916e-b74a82622f68" href="https://job-openings.monster.com/economics-education-sme-atkinson-nh-us-gex-inc/215090143" onclick="clickJobTitle('plid=530&amp;pcid=3&amp;poccid=11915','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;ECONOMICS EDUCATION SME&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xw288169336wx_GEX, Inc.&quot;,&quot;eVar31&quot;:&quot;ATKINSON_NH_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-03-14T12:00&quot;,&quot;eVar53&quot;:&quot;2500401001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;logo&quot;}')">
#           ECONOMICS EDUCATION SME
#          </a>
#         </h2>
#        </header>
#        <div class="company">
#         <span class="name">
#          GEX, Inc.
#         </span>
#         <ul class="list-inline">
#         </ul>
#        </div>
#        <div class="location">
#         <span class="name">
#          ATKINSON, NH
#         </span>
#        </div>
#       </div>
#       <div class="meta flex-col">
#        <time datetime="2017-05-26T12:00">
#         7 days ago
#        </time>
#        <span class="mux-tooltip applied-only" data-mux="tooltip" title="Applied">
#         <i aria-hidden="true" class="icon icon-applied">
#         </i>
#         <span class="sr-only">
#          Applied
#         </span>
#        </span>
#        <span class="mux-tooltip saved-only" data-mux="tooltip" title="Saved">
#         <i aria-hidden="true" class="icon icon-saved">
#         </i>
#         <span class="sr-only">
#          Saved
#         </span>
#        </span>
#       </div>
#      </div>
#     </section>
#     <section class="card-content" data-jobid="216859301" data-postingid="2f2275c1-3fca-49cb-985e-0b17867b8630" onclick="MKImpressionTrackingMouseDownHijack(this, event)">
#      <div class="flex-row">
#       <div class="mux-company-logo thumbnail">
#       </div>
#       <div class="summary">
#        <header class="card-header">
#         <h2 class="title">
#          <a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="9008" data-m_impr_j_coc="xhj270_119957x" data-m_impr_j_jawsid="427647264" data-m_impr_j_jobid="216859301" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="42.9652" data-m_impr_j_lid="706" data-m_impr_j_long="-72.9074" data-m_impr_j_occid="11910" data-m_impr_j_p="8" data-m_impr_j_postingid="2f2275c1-3fca-49cb-985e-0b17867b8630" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="2ebe32c4-82ae-43be-b7e5-e7712c73e23a" href="https://job-openings.monster.com/economic-development-director-mount-snow-vt-us-town-of-dover/216859301" onclick="clickJobTitle('plid=706&amp;pcid=9008&amp;poccid=11910','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;ECONOMIC DEVELOPMENT DIRECTOR&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xhj270_119957x_TOWN OF DOVER&quot;,&quot;eVar31&quot;:&quot;Mount Snow_VT_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-03-21T12:00&quot;,&quot;eVar53&quot;:&quot;1100003001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">
#           ECONOMIC DEVELOPMENT DIRECTOR
#          </a>
#         </h2>
#        </header>
#        <div class="company">
#         <span class="name">
#          TOWN OF DOVER
#         </span>
#         <ul class="list-inline">
#         </ul>
#        </div>
#        <div class="location">
#         <span class="name">
#          Mount Snow, VT
#         </span>
#        </div>
#       </div>
#       <div class="meta flex-col">
#        <time datetime="2017-05-26T12:00">
#         Posted today
#        </time>
#        <span class="mux-tooltip applied-only" data-mux="tooltip" title="Applied">
#         <i aria-hidden="true" class="icon icon-applied">
#         </i>
#         <span class="sr-only">
#          Applied
#         </span>
#        </span>
#        <span class="mux-tooltip saved-only" data-mux="tooltip" title="Saved">
#         <i aria-hidden="true" class="icon icon-saved">
#         </i>
#         <span class="sr-only">
#          Saved
#         </span>
#        </span>
#       </div>
#      </div>
#     </section>
#     <section class="card-content" data-jobid="216184337" data-postingid="1223f32e-5717-421c-bfde-31833d16b55f" onclick="MKImpressionTrackingMouseDownHijack(this, event)">
#      <div class="flex-row">
#       <div class="mux-company-logo thumbnail">
#       </div>
#       <div class="summary">
#        <header class="card-header">
#         <h2 class="title">
#          <a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="9008" data-m_impr_j_coc="xbuff_univofnvx" data-m_impr_j_jawsid="423682262" data-m_impr_j_jobid="216184337" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="36.1095" data-m_impr_j_lid="541" data-m_impr_j_long="-115.1438" data-m_impr_j_occid="11934" data-m_impr_j_p="9" data-m_impr_j_postingid="1223f32e-5717-421c-bfde-31833d16b55f" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="d878ea36-11a5-4a00-9f93-53ad33e5571c" href="https://job-openings.monster.com/project-manager-office-of-economic-development-las-vegas-nv-us-university-of-nevada-las-vegas/216184337" onclick="clickJobTitle('plid=541&amp;pcid=9008&amp;poccid=11934','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Project Manager, Office of Economic Development&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xbuff_univofnvx_University of Nevada, Las Vegas&quot;,&quot;eVar31&quot;:&quot;Las Vegas_NV_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-02-24T12:00&quot;,&quot;eVar53&quot;:&quot;1300093001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">
#           Project Manager, Office of Economic Development
#          </a>
#         </h2>
#        </header>
#        <div class="company">
#         <span class="name">
#          University of Nevada, Las Vegas
#         </span>
#         <ul class="list-inline">
#         </ul>
#        </div>
#        <div class="location">
#         <span class="name">
#          Las Vegas, NV
#         </span>
#        </div>
#       </div>
#       <div class="meta flex-col">
#        <time datetime="2017-05-26T12:00">
#         26 days ago
#        </time>
#        <span class="mux-tooltip applied-only" data-mux="tooltip" title="Applied">
#         <i aria-hidden="true" class="icon icon-applied">
#         </i>
#         <span class="sr-only">
#          Applied
#         </span>
#        </span>
#        <span class="mux-tooltip saved-only" data-mux="tooltip" title="Saved">
#         <i aria-hidden="true" class="icon icon-saved">
#         </i>
#         <span class="sr-only">
#          Saved
#         </span>
#        </span>
#       </div>
#      </div>
#     </section>
#     <section class="card-content" data-jobid="5941e56d-0985-4b4f-b42e-c8ed825cf86b" onclick="MKImpressionTrackingMouseDownHijack(this, event)">
#      <div class="flex-row">
#       <div class="mux-company-logo thumbnail">
#       </div>
#       <div class="summary">
#        <header class="card-header">
#         <h2 class="title">
#          <a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="2" data-m_impr_j_coc="" data-m_impr_j_jawsid="422005526" data-m_impr_j_jobid="0" data-m_impr_j_jpm="1" data-m_impr_j_jpt="2" data-m_impr_j_lat="29.4241" data-m_impr_j_lid="624" data-m_impr_j_long="-98.4937" data-m_impr_j_occid="14874" data-m_impr_j_p="10" data-m_impr_j_postingid="5941e56d-0985-4b4f-b42e-c8ed825cf86b" data-m_impr_j_pvc="27aa7533-7b3b-4108-84cc-8faf5c5bbc61" data-m_impr_s_t="t" data-m_impr_uuid="03379e09-8039-4c6f-ac63-f10689c46c8a" href="https://job-openings.monster.com/vp-real-estate-technology-san-antonio-tx-us-penfed-credit-union/5941e56d-0985-4b4f-b42e-c8ed825cf86b" onclick="clickJobTitle('plid=624&amp;pcid=2&amp;poccid=14874','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;VP Real Estate Technology&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;_PenFed Credit Union&quot;,&quot;eVar31&quot;:&quot;San Antonio_TX_&quot;,&quot;prop24&quot;:&quot;2020-03-16T12:00&quot;,&quot;eVar53&quot;:&quot;1100052001001&quot;,&quot;eVar50&quot;:&quot;PPC&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">
#           VP Real Estate Technology
#          </a>
#         </h2>
#        </header>
#        <div class="company">
#         <span class="name">
#          PenFed Credit Union
#         </span>
#         <ul class="list-inline">
#         </ul>
#        </div>
#        <div class="location">
#         <span class="name">
#          San Antonio, TX
#         </span>
#        </div>
#       </div>
#       <div class="meta flex-col">
#        <time datetime="2017-05-26T12:00">
#         5 days ago
#        </time>
#        <span class="mux-tooltip applied-only" data-mux="tooltip" title="Applied">
#         <i aria-hidden="true" class="icon icon-applied">
#         </i>
#         <span class="sr-only">
#          Applied
#         </span>
#        </span>
#        <span class="mux-tooltip saved-only" data-mux="tooltip" title="Saved">
#         <i aria-hidden="true" class="icon icon-saved">
#         </i>
#         <span class="sr-only">
#          Saved
#         </span>
#        </span>
#       </div>
#      </div>
#     </section>
#     <section class="card-content" data-jobid="216838335" data-postingid="4268b667-41e4-4e82-933f-f866b37befc4" data-ssr="true" onclick="MKImpressionTrackingMouseDownHijack(this, event)">
#      <p class="entry">
#       Interesting opportunity
#      </p>
#      <div class="flex-row">
#       <div class="mux-company-logo thumbnail is-loaded">
#        <img alt="Amazon Corporate LLC" src="https://media.newjobs.com/clu/xama/xamazonx/branding/54/Amazon-logo-637196280106671504.gif"/>
#       </div>
#       <div class="summary">
#        <header class="card-header">
#         <h2 class="title">
#          <a data-bypass="true" data-m_impr_a_placement_id="JSRSEC" data-m_impr_j_cid="9008" data-m_impr_j_coc="xwag2321849x" data-m_impr_j_jawsid="427526412" data-m_impr_j_jobid="216838335" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="47.6388" data-m_impr_j_lid="0" data-m_impr_j_long="-122.37" data-m_impr_j_occid="11910" data-m_impr_j_p="11" data-m_impr_j_postingid="4268b667-41e4-4e82-933f-f866b37befc4" data-m_impr_j_pvc="monster" data-m_impr_s_t="m" data-m_impr_uuid="b26f9364-3e06-4a22-8762-5dc40e0edfb3" href="https://job-openings.monster.com/economist-seattle-wa-us-amazon-corporate-llc/216838335" onclick="clickJobTitle('plid=0&amp;pcid=9008&amp;poccid=11910','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;events.event65&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Economist&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSRSEC&quot;,&quot;eVar26&quot;:&quot;xwag2321849x_Amazon Corporate LLC&quot;,&quot;eVar31&quot;:&quot;Seattle_WA_&quot;,&quot;prop22&quot;:&quot;Full-Time&quot;,&quot;prop24&quot;:&quot;2020-03-20T05:39&quot;,&quot;eVar47&quot;:&quot;monster&quot;,&quot;eVar53&quot;:&quot;1900269001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;logo&quot;}')">
#           Economist
#          </a>
#         </h2>
#        </header>
#        <div class="company">
#         <span class="name">
#          Amazon Corporate LLC
#         </span>
#         <ul class="list-inline">
#         </ul>
#        </div>
#        <div class="location">
#         <span class="name">
#          Seattle, WA
#         </span>
#        </div>
#       </div>
#       <div class="meta flex-col">
#        <time datetime="2017-05-26T12:00">
#         1 day ago
#        </time>
#        <span class="mux-tooltip applied-only" data-mux="tooltip" title="Applied">
#         <i aria-hidden="true" class="icon icon-applied">
#         </i>
#         <span class="sr-only">
#          Applied
#         </span>
#        </span>
#        <span class="mux-tooltip saved-only" data-mux="tooltip" title="Saved">
#         <i aria-hidden="true" class="icon icon-saved">
#         </i>
#         <span class="sr-only">
#          Saved
#         </span>
#        </span>
#       </div>
#      </div>
#     </section>
#     <section class="card-content" data-jobid="216401612" data-postingid="1079a9fd-d526-46e1-8822-e98afbd467dc" onclick="MKImpressionTrackingMouseDownHijack(this, event)">
#      <div class="flex-row">
#       <div class="mux-company-logo thumbnail is-loaded">
#        <img alt="New York Power Authority" src="https://coda.newjobs.com/api/imagesproxy/ms/clu/xnyp/xnypax/branding/157856/New-York-Power-Authority-logo.jpg"/>
#       </div>
#       <div class="summary">
#        <header class="card-header">
#         <h2 class="title">
#          <a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="11" data-m_impr_j_coc="xnypax" data-m_impr_j_jawsid="425624315" data-m_impr_j_jobid="216401612" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="41.0339" data-m_impr_j_lid="556" data-m_impr_j_long="-73.763" data-m_impr_j_occid="11892" data-m_impr_j_p="12" data-m_impr_j_postingid="1079a9fd-d526-46e1-8822-e98afbd467dc" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="4e2d6ad3-2f06-4ba8-9aaa-6784d816313d" href="https://job-openings.monster.com/director-product-marketing-white-plains-ny-us-new-york-power-authority/216401612" onclick="clickJobTitle('plid=556&amp;pcid=11&amp;poccid=11892','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Director Product Marketing&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xnypax_New York Power Authority&quot;,&quot;eVar31&quot;:&quot;White Plains_NY_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-03-04T12:00&quot;,&quot;eVar53&quot;:&quot;1100007001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;logo&quot;}')">
#           Director Product Marketing
#          </a>
#         </h2>
#        </header>
#        <div class="company">
#         <span class="name">
#          New York Power Authority
#         </span>
#         <ul class="list-inline">
#         </ul>
#        </div>
#        <div class="location">
#         <span class="name">
#          White Plains, NY
#         </span>
#        </div>
#       </div>
#       <div class="meta flex-col">
#        <time datetime="2017-05-26T12:00">
#         17 days ago
#        </time>
#        <span class="mux-tooltip applied-only" data-mux="tooltip" title="Applied">
#         <i aria-hidden="true" class="icon icon-applied">
#         </i>
#         <span class="sr-only">
#          Applied
#         </span>
#        </span>
#        <span class="mux-tooltip saved-only" data-mux="tooltip" title="Saved">
#         <i aria-hidden="true" class="icon icon-saved">
#         </i>
#         <span class="sr-only">
#          Saved
#         </span>
#        </span>
#       </div>
#      </div>
#     </section>
#     <section class="card-content" data-jobid="216803807" data-postingid="162373da-ff50-44bf-beff-d5b68c054763" onclick="MKImpressionTrackingMouseDownHijack(this, event)">
#      <div class="flex-row">
#       <div class="mux-company-logo thumbnail is-loaded">
#        <img alt="Advantage Resourcing" src="https://media.newjobs.com/clu/xtac/xtacworldx/branding/13268/Advantage-Resourcing-logo.gif"/>
#       </div>
#       <div class="summary">
#        <header class="card-header">
#         <h2 class="title">
#          <a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="11" data-m_impr_j_coc="xtacworldx" data-m_impr_j_jawsid="427344929" data-m_impr_j_jobid="216803807" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="42.3298" data-m_impr_j_lid="470" data-m_impr_j_long="-83.1861" data-m_impr_j_occid="11892" data-m_impr_j_p="13" data-m_impr_j_postingid="162373da-ff50-44bf-beff-d5b68c054763" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="a6833009-20a2-4f44-bc98-810e3b4f63ec" href="https://job-openings.monster.com/sales-planning-analytics-dearborn-mi-us-advantage-resourcing/216803807" onclick="clickJobTitle('plid=470&amp;pcid=11&amp;poccid=11892','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Sales Planning Analytics&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xtacworldx_Advantage Resourcing&quot;,&quot;eVar31&quot;:&quot;Dearborn_MI_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-03-19T12:00&quot;,&quot;eVar53&quot;:&quot;4100683001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;logo&quot;}')">
#           Sales Planning Analytics
#          </a>
#         </h2>
#        </header>
#        <div class="company">
#         <span class="name">
#          Advantage Resourcing
#         </span>
#         <ul class="list-inline">
#         </ul>
#        </div>
#        <div class="location">
#         <span class="name">
#          Dearborn, MI
#         </span>
#        </div>
#       </div>
#       <div class="meta flex-col">
#        <time datetime="2017-05-26T12:00">
#         2 days ago
#        </time>
#        <span class="mux-tooltip applied-only" data-mux="tooltip" title="Applied">
#         <i aria-hidden="true" class="icon icon-applied">
#         </i>
#         <span class="sr-only">
#          Applied
#         </span>
#        </span>
#        <span class="mux-tooltip saved-only" data-mux="tooltip" title="Saved">
#         <i aria-hidden="true" class="icon icon-saved">
#         </i>
#         <span class="sr-only">
#          Saved
#         </span>
#        </span>
#       </div>
#      </div>
#     </section>
#     <section class="card-content" data-jobid="c8f88771-a8fa-49c1-b6da-bb396d78f9ac" onclick="MKImpressionTrackingMouseDownHijack(this, event)">
#      <div class="flex-row">
#       <div class="mux-company-logo thumbnail is-loaded">
#        <img alt="Quicken Loans" src="https://media.newjobs.com/clu/xw26/xw264170552wx/branding/118809/Quicken-Loans-logo.png"/>
#       </div>
#       <div class="summary">
#        <header class="card-header">
#         <h2 class="title">
#          <a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="9008" data-m_impr_j_coc="" data-m_impr_j_jawsid="426263948" data-m_impr_j_jobid="389139" data-m_impr_j_jpm="1" data-m_impr_j_jpt="2" data-m_impr_j_lat="42.3314" data-m_impr_j_lid="470" data-m_impr_j_long="-83.0503" data-m_impr_j_occid="11934" data-m_impr_j_p="14" data-m_impr_j_postingid="c8f88771-a8fa-49c1-b6da-bb396d78f9ac" data-m_impr_j_pvc="e8e7415b-3f42-402b-9bc9-401a7ab9203c" data-m_impr_s_t="t" data-m_impr_uuid="e7386523-61b0-49b1-ae8f-05d37c391cc6" href="https://job-openings.monster.com/loss-analyst-detroit-mi-us-quicken-loans/c8f88771-a8fa-49c1-b6da-bb396d78f9ac" onclick="clickJobTitle('plid=470&amp;pcid=9008&amp;poccid=11934','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Loss Analyst&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;_Quicken Loans&quot;,&quot;eVar31&quot;:&quot;Detroit_MI_&quot;,&quot;prop24&quot;:&quot;2020-03-18T12:00&quot;,&quot;eVar53&quot;:&quot;1300093001001&quot;,&quot;eVar50&quot;:&quot;PPC&quot;,&quot;eVar74&quot;:&quot;logo&quot;}')">
#           Loss Analyst
#          </a>
#         </h2>
#        </header>
#        <div class="company">
#         <span class="name">
#          Quicken Loans
#         </span>
#         <ul class="list-inline">
#         </ul>
#        </div>
#        <div class="location">
#         <span class="name">
#          Detroit, MI
#         </span>
#        </div>
#       </div>
#       <div class="meta flex-col">
#        <time datetime="2017-05-26T12:00">
#         3 days ago
#        </time>
#        <span class="mux-tooltip applied-only" data-mux="tooltip" title="Applied">
#         <i aria-hidden="true" class="icon icon-applied">
#         </i>
#         <span class="sr-only">
#          Applied
#         </span>
#        </span>
#        <span class="mux-tooltip saved-only" data-mux="tooltip" title="Saved">
#         <i aria-hidden="true" class="icon icon-saved">
#         </i>
#         <span class="sr-only">
#          Saved
#         </span>
#        </span>
#       </div>
#      </div>
#     </section>
#     <section class="card-content" data-jobid="216170327" data-postingid="6b868ecc-99b3-4d11-af7f-9cd2063116d5" onclick="MKImpressionTrackingMouseDownHijack(this, event)">
#      <div class="flex-row">
#       <div class="mux-company-logo thumbnail">
#       </div>
#       <div class="summary">
#        <header class="card-header">
#         <h2 class="title">
#          <a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="11" data-m_impr_j_coc="xsphterex" data-m_impr_j_jawsid="423634471" data-m_impr_j_jobid="216170327" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="47.6739" data-m_impr_j_lid="896" data-m_impr_j_long="-122.1216" data-m_impr_j_occid="11892" data-m_impr_j_p="15" data-m_impr_j_postingid="6b868ecc-99b3-4d11-af7f-9cd2063116d5" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="be6f78bf-5cd4-4011-8b35-cc7ca5a5c4dc" href="https://job-openings.monster.com/global-forecasting-economic-planning-manager-redmond-wa-us-terex-corporation/216170327" onclick="clickJobTitle('plid=896&amp;pcid=11&amp;poccid=11892','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Global Forecasting \u0026 Economic Planning Manager&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xsphterex_Terex Corporation&quot;,&quot;eVar31&quot;:&quot;Redmond_WA_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-03-09T12:00&quot;,&quot;eVar53&quot;:&quot;1101115002005&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">
#           Global Forecasting &amp; Economic Planning Manager
#          </a>
#         </h2>
#        </header>
#        <div class="company">
#         <span class="name">
#          Terex Corporation
#         </span>
#         <ul class="list-inline">
#         </ul>
#        </div>
#        <div class="location">
#         <span class="name">
#          Redmond, WA
#         </span>
#        </div>
#       </div>
#       <div class="meta flex-col">
#        <time datetime="2017-05-26T12:00">
#         12 days ago
#        </time>
#        <span class="mux-tooltip applied-only" data-mux="tooltip" title="Applied">
#         <i aria-hidden="true" class="icon icon-applied">
#         </i>
#         <span class="sr-only">
#          Applied
#         </span>
#        </span>
# ...
#          Applied
#         </span>
#        </span>
#        <span class="mux-tooltip saved-only" data-mux="tooltip" title="Saved">
#         <i aria-hidden="true" class="icon icon-saved">
#         </i>
#         <span class="sr-only">
#          Saved
#         </span>
#        </span>
#       </div>
#      </div>
#     </section>
#     <section class="card-content" data-jobid="216852703" data-postingid="808c87a5-6301-4ea3-8f04-fed8d233b7e6" onclick="MKImpressionTrackingMouseDownHijack(this, event)">
#      <div class="flex-row">
#       <div class="mux-company-logo thumbnail">
#       </div>
#       <div class="summary">
#        <header class="card-header">
#         <h2 class="title">
#          <a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="1" data-m_impr_j_coc="xmyhrx" data-m_impr_j_jawsid="427563703" data-m_impr_j_jobid="216852703" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="40.7286" data-m_impr_j_lid="532" data-m_impr_j_long="-74.0775" data-m_impr_j_occid="11893" data-m_impr_j_p="21" data-m_impr_j_postingid="808c87a5-6301-4ea3-8f04-fed8d233b7e6" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="3f3b7967-b67a-46cf-bba6-abf2ec5dd6c7" href="https://job-openings.monster.com/model-risk-director-quant-model-validation-jersey-city-nj-us-my-hr-supplier/216852703" onclick="clickJobTitle('plid=532&amp;pcid=1&amp;poccid=11893','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Model Risk Director (Quant Model Validation)&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xmyhrx_MY HR Supplier&quot;,&quot;eVar31&quot;:&quot;Jersey City_NJ_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-03-20T12:00&quot;,&quot;eVar53&quot;:&quot;1100014001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">
#           Model Risk Director (Quant Model Validation)
#          </a>
#         </h2>
#        </header>
#        <div class="company">
#         <span class="name">
#          MY HR Supplier
#         </span>
#         <ul class="list-inline">
#         </ul>
#        </div>
#        <div class="location">
#         <span class="name">
#          Jersey City, NJ
#         </span>
#        </div>
#       </div>
#       <div class="meta flex-col">
#        <time datetime="2017-05-26T12:00">
#         1 day ago
#        </time>
#        <span class="mux-tooltip applied-only" data-mux="tooltip" title="Applied">
#         <i aria-hidden="true" class="icon icon-applied">
#         </i>
#         <span class="sr-only">
#          Applied
#         </span>
#        </span>
#        <span class="mux-tooltip saved-only" data-mux="tooltip" title="Saved">
#         <i aria-hidden="true" class="icon icon-saved">
#         </i>
#         <span class="sr-only">
#          Saved
#         </span>
#        </span>
#       </div>
#      </div>
#     </section>
#     <section class="card-content" data-jobid="216131754" data-postingid="61e072ff-4b87-4693-96a1-4a115310c7b6" onclick="MKImpressionTrackingMouseDownHijack(this, event)">
#      <div class="flex-row">
#       <div class="mux-company-logo thumbnail">
#       </div>
#       <div class="summary">
#        <header class="card-header">
#         <h2 class="title">
#          <a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="1" data-m_impr_j_coc="xadptotalx" data-m_impr_j_jawsid="423359005" data-m_impr_j_jobid="216131754" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="41.678" data-m_impr_j_lid="890" data-m_impr_j_long="-88.1448" data-m_impr_j_occid="11981" data-m_impr_j_p="22" data-m_impr_j_postingid="61e072ff-4b87-4693-96a1-4a115310c7b6" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="402709b5-4d60-4d94-8980-7266bbb276a8" href="https://job-openings.monster.com/tax-specialist-bolingbrook-il-us-beko-us-inc/216131754" onclick="clickJobTitle('plid=890&amp;pcid=1&amp;poccid=11981','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Tax Specialist&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xadptotalx_BEKO US INC&quot;,&quot;eVar31&quot;:&quot;Bolingbrook_IL_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-03-20T12:00&quot;,&quot;eVar53&quot;:&quot;1300116001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">
#           Tax Specialist
#          </a>
#         </h2>
#        </header>
#        <div class="company">
#         <span class="name">
#          BEKO US INC
#         </span>
#         <ul class="list-inline">
#         </ul>
#        </div>
#        <div class="location">
#         <span class="name">
#          Bolingbrook, IL
#         </span>
#        </div>
#       </div>
#       <div class="meta flex-col">
#        <time datetime="2017-05-26T12:00">
#         1 day ago
#        </time>
#        <span class="mux-tooltip applied-only" data-mux="tooltip" title="Applied">
#         <i aria-hidden="true" class="icon icon-applied">
#         </i>
#         <span class="sr-only">
#          Applied
#         </span>
#        </span>
#        <span class="mux-tooltip saved-only" data-mux="tooltip" title="Saved">
#         <i aria-hidden="true" class="icon icon-saved">
#         </i>
#         <span class="sr-only">
#          Saved
#         </span>
#        </span>
#       </div>
#      </div>
#     </section>
#     <section class="card-content" data-jobid="216841798" data-postingid="59c84b4d-017a-4581-bd85-c6b39ff7916d" onclick="MKImpressionTrackingMouseDownHijack(this, event)">
#      <div class="flex-row">
#       <div class="mux-company-logo thumbnail">
#       </div>
#       <div class="summary">
#        <header class="card-header">
#         <h2 class="title">
#          <a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="11" data-m_impr_j_coc="xsphcobhamx" data-m_impr_j_jawsid="427530711" data-m_impr_j_jobid="216841798" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="32.7153" data-m_impr_j_lid="354" data-m_impr_j_long="-117.1573" data-m_impr_j_occid="11892" data-m_impr_j_p="23" data-m_impr_j_postingid="59c84b4d-017a-4581-bd85-c6b39ff7916d" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="1684eb95-6aba-42f5-accb-03a0dbe65a16" href="https://job-openings.monster.com/project-program-control-analyst-san-diego-ca-us-cobham/216841798" onclick="clickJobTitle('plid=354&amp;pcid=11&amp;poccid=11892','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Project / Program Control Analyst&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xsphcobhamx_Cobham&quot;,&quot;eVar31&quot;:&quot;San Diego_CA_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-03-20T12:00&quot;,&quot;eVar53&quot;:&quot;1300093001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">
#           Project / Program Control Analyst
#          </a>
#         </h2>
#        </header>
#        <div class="company">
#         <span class="name">
#          Cobham
#         </span>
#         <ul class="list-inline">
#         </ul>
#        </div>
#        <div class="location">
#         <span class="name">
#          San Diego, CA
#         </span>
#        </div>
#       </div>
#       <div class="meta flex-col">
#        <time datetime="2017-05-26T12:00">
#         1 day ago
#        </time>
#        <span class="mux-tooltip applied-only" data-mux="tooltip" title="Applied">
#         <i aria-hidden="true" class="icon icon-applied">
#         </i>
#         <span class="sr-only">
#          Applied
#         </span>
#        </span>
#        <span class="mux-tooltip saved-only" data-mux="tooltip" title="Saved">
#         <i aria-hidden="true" class="icon icon-saved">
#         </i>
#         <span class="sr-only">
#          Saved
#         </span>
#        </span>
#       </div>
#      </div>
#     </section>
#     <section class="card-content" data-jobid="216472289" data-postingid="2bc10bbe-5f56-4ae6-ad3f-dcc0491fdc50" onclick="MKImpressionTrackingMouseDownHijack(this, event)">
#      <div class="flex-row">
#       <div class="mux-company-logo thumbnail">
#       </div>
#       <div class="summary">
#        <header class="card-header">
#         <h2 class="title">
#          <a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="11" data-m_impr_j_coc="xsphhoneyx" data-m_impr_j_jawsid="425920656" data-m_impr_j_jobid="216472289" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="33.8358" data-m_impr_j_lid="348" data-m_impr_j_long="-118.3407" data-m_impr_j_occid="11892" data-m_impr_j_p="24" data-m_impr_j_postingid="2bc10bbe-5f56-4ae6-ad3f-dcc0491fdc50" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="8d1fc930-f80a-462e-a6ee-d8a97864b7af" href="https://job-openings.monster.com/program-planning-control-analyst-iii-torrance-ca-us-honeywell/216472289" onclick="clickJobTitle('plid=348&amp;pcid=11&amp;poccid=11892','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Program Planning \u0026 Control Analyst III&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xsphhoneyx_Honeywell&quot;,&quot;eVar31&quot;:&quot;Torrance_CA_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-03-20T12:00&quot;,&quot;eVar53&quot;:&quot;1300093001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">
#           Program Planning &amp; Control Analyst III
#          </a>
#         </h2>
#        </header>
#        <div class="company">
#         <span class="name">
#          Honeywell
#         </span>
#         <ul class="list-inline">
#         </ul>
#        </div>
#        <div class="location">
#         <span class="name">
#          Torrance, CA
#         </span>
#        </div>
#       </div>
#       <div class="meta flex-col">
#        <time datetime="2017-05-26T12:00">
#         1 day ago
#        </time>
#        <span class="mux-tooltip applied-only" data-mux="tooltip" title="Applied">
#         <i aria-hidden="true" class="icon icon-applied">
#         </i>
#         <span class="sr-only">
#          Applied
#         </span>
#        </span>
#        <span class="mux-tooltip saved-only" data-mux="tooltip" title="Saved">
#         <i aria-hidden="true" class="icon icon-saved">
#         </i>
#         <span class="sr-only">
#          Saved
#         </span>
#        </span>
#       </div>
#      </div>
#     </section>
#     <section class="card-content" data-jobid="216621046" data-postingid="a5e0995e-fb83-447e-8020-7a8925f6cd1b" onclick="MKImpressionTrackingMouseDownHijack(this, event)">
#      <div class="flex-row">
#       <div class="mux-company-logo thumbnail">
#       </div>
#       <div class="summary">
#        <header class="card-header">
#         <h2 class="title">
#          <a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="1" data-m_impr_j_coc="xw146445879wx" data-m_impr_j_jawsid="426455680" data-m_impr_j_jobid="216621046" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="40.6527" data-m_impr_j_lid="534" data-m_impr_j_long="-74.2601" data-m_impr_j_occid="11817" data-m_impr_j_p="25" data-m_impr_j_postingid="a5e0995e-fb83-447e-8020-7a8925f6cd1b" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="d2845330-4fa9-437b-abc2-8291c6dac1d9" href="https://job-openings.monster.com/staff-accountant-roselle-nj-us-pamarco-global-graphics/216621046" onclick="clickJobTitle('plid=534&amp;pcid=1&amp;poccid=11817','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Staff Accountant&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xw146445879wx_Pamarco Global Graphics&quot;,&quot;eVar31&quot;:&quot;Roselle_NJ_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-03-19T12:00&quot;,&quot;eVar53&quot;:&quot;1300101001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">
#           Staff Accountant
#          </a>
#         </h2>
#        </header>
#        <div class="company">
#         <span class="name">
#          Pamarco Global Graphics
#         </span>
#         <ul class="list-inline">
#         </ul>
#        </div>
#        <div class="location">
#         <span class="name">
#          Roselle, NJ
#         </span>
#        </div>
#       </div>
#       <div class="meta flex-col">
#        <time datetime="2017-05-26T12:00">
#         2 days ago
#        </time>
#        <span class="mux-tooltip applied-only" data-mux="tooltip" title="Applied">
#         <i aria-hidden="true" class="icon icon-applied">
#         </i>
#         <span class="sr-only">
#          Applied
#         </span>
#        </span>
#        <span class="mux-tooltip saved-only" data-mux="tooltip" title="Saved">
#         <i aria-hidden="true" class="icon icon-saved">
#         </i>
#         <span class="sr-only">
#          Saved
#         </span>
#        </span>
#       </div>
#      </div>
#     </section>
#     <section class="card-content" data-jobid="216812628" data-postingid="486cdfe5-11fa-4c06-9822-78558b69f437" onclick="MKImpressionTrackingMouseDownHijack(this, event)">
#      <div class="flex-row">
#       <div class="mux-company-logo thumbnail">
#       </div>
#       <div class="summary">
#        <header class="card-header">
#         <h2 class="title">
#          <a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="5623" data-m_impr_j_coc="xlnpmediax" data-m_impr_j_jawsid="427364927" data-m_impr_j_jobid="216812628" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="40.0115" data-m_impr_j_lid="703" data-m_impr_j_long="-76.3553" data-m_impr_j_occid="11781" data-m_impr_j_p="26" data-m_impr_j_postingid="486cdfe5-11fa-4c06-9822-78558b69f437" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="a553507a-ccae-4a2a-b8d6-4df20affd3ae" href="https://job-openings.monster.com/business-editor-lancaster-pa-us-lnp-media-group/216812628" onclick="clickJobTitle('plid=703&amp;pcid=5623&amp;poccid=11781','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Business Editor&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xlnpmediax_LNP Media Group&quot;,&quot;eVar31&quot;:&quot;Lancaster_PA_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-03-19T12:00&quot;,&quot;eVar53&quot;:&quot;2700439001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">
#           Business Editor
#          </a>
#         </h2>
#        </header>
#        <div class="company">
#         <span class="name">
#          LNP Media Group
#         </span>
#         <ul class="list-inline">
#         </ul>
#        </div>
#        <div class="location">
#         <span class="name">
#          Lancaster, PA
#         </span>
#        </div>
#       </div>
#       <div class="meta flex-col">
#        <time datetime="2017-05-26T12:00">
#         2 days ago
#        </time>
#        <span class="mux-tooltip applied-only" data-mux="tooltip" title="Applied">
#         <i aria-hidden="true" class="icon icon-applied">
#         </i>
#         <span class="sr-only">
#          Applied
#         </span>
#        </span>
#        <span class="mux-tooltip saved-only" data-mux="tooltip" title="Saved">
#         <i aria-hidden="true" class="icon icon-saved">
#         </i>
#         <span class="sr-only">
#          Saved
#         </span>
#        </span>
#       </div>
#      </div>
#     </section>
#    </div>
#    <a class="mux-btn btn-secondary load-more-btn" data-action="fetch" href="https://www.monster.com/jobs/search/?page=2" id="loadMoreJobs" role="button">
#     Load more jobs
#    </a>
#    <a class="mux-btn btn-secondary no-more-jobs-btn disabled" id="noMoreResults" role="button" style="display:none">
#     No More Results
#    </a>
#   </div>
#  </div>
# </div>

# %% [markdown]
# So that is a part of the HTML - all the results of the search in the job site. You can see that every job posting is wrapped in an element that is called "card-content". Within that you have subelements : title of the job, location, company. You are interested in these. You can extract them.
#
# Two HTML objects are important here : `section`, `class` and `div`. Think of it like that : in the `section` which class (or name) is "card-header", you have the `div` which class (name) is "title", the `div` which class is "location".... Hence you infer that "card-content" identifies the card of a unique job !
#
# Hence, you want to ask Python to "pick each section which class is "card-content"" and put those in a sort of list.

# %%
job_elems = results.find_all('section', class_='card-content')
print(type(job_elems))
# Out:
# <class 'bs4.element.ResultSet'>

# %% [markdown]
# You have this sort of list, which you can see is an object specific to the BeautifulSoup package.

# %%
job_elems[2]
# Out:
# <section class="card-content" data-jobid="216493284" data-postingid="9f860997-6841-4cc5-942d-7856190cc6cb" onclick="MKImpressionTrackingMouseDownHijack(this, event)">
# <div class="flex-row">
# <div class="mux-company-logo thumbnail"></div>
# <div class="summary">
# <header class="card-header">
# <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="559" data-m_impr_j_coc="xtime_nyoscx" data-m_impr_j_jawsid="425967836" data-m_impr_j_jobid="216493284" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="42.6525" data-m_impr_j_lid="544" data-m_impr_j_long="-73.7563" data-m_impr_j_occid="11866" data-m_impr_j_p="2" data-m_impr_j_postingid="9f860997-6841-4cc5-942d-7856190cc6cb" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="75217ea2-2cef-4480-8abe-de16764851b7" href="https://job-openings.monster.com/senior-economist-albany-ny-us-nys-office-of-the-state-comptroller/216493284" onclick="clickJobTitle('plid=544&amp;pcid=559&amp;poccid=11866','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Senior Economist&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xtime_nyoscx_NYS Office of the State Comptroller&quot;,&quot;eVar31&quot;:&quot;Albany_NY_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-03-20T12:00&quot;,&quot;eVar53&quot;:&quot;1900269001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">Senior Economist
# </a></h2>
# </header>
# <div class="company">
# <span class="name">NYS Office of the State Comptroller</span>
# <ul class="list-inline">
# </ul>
# </div>
# <div class="location">
# <span class="name">
# Albany, NY
# </span>
# </div>
# </div>
# <div class="meta flex-col">
# <time datetime="2017-05-26T12:00">1 day ago</time>
# <span class="mux-tooltip applied-only" data-mux="tooltip" title="Applied">
# <i aria-hidden="true" class="icon icon-applied"></i>
# <span class="sr-only">Applied</span>
# </span>
# <span class="mux-tooltip saved-only" data-mux="tooltip" title="Saved">
# <i aria-hidden="true" class="icon icon-saved"></i>
# <span class="sr-only">Saved</span>
# </span>
# </div>
# </div>
# </section>

# %% [markdown]
# You picked the second job element. You're heading to something clean. But you want to get rid of all the HTML you don't care about. You essentially want the job title, the location and the company. You're gonna do the exact same as before but narrowing the window. You want, in each job, to get only the lines "title", "location", "company".

# %%
for job_elem in job_elems:
    title=job_elem.find('h2', class_='title')
    location=job_elem.find('div', class_='location')
    company=job_elem.find('div', class_='company')
    print(title)
    print(location)
    print(company)
    print()
# Out:
# <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="11" data-m_impr_j_coc="xw301558987wx" data-m_impr_j_jawsid="427022700" data-m_impr_j_jobid="216739002" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="0" data-m_impr_j_lid="573" data-m_impr_j_long="0" data-m_impr_j_occid="11892" data-m_impr_j_p="1" data-m_impr_j_postingid="f3991871-0cf7-4a34-bffc-9674024247db" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="f97f7172-f9be-4241-820d-3ce00786b919" href="https://job-openings.monster.com/transportation-economist-mill-creek-building-odot-or-us-oregon-department-of-transportation/216739002" onclick="clickJobTitle('plid=573&amp;pcid=11&amp;poccid=11892','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Transportation Economist&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xw301558987wx_Oregon Department of Transportation&quot;,&quot;eVar31&quot;:&quot;Mill Creek Building - ODOT_OR_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-03-16T12:00&quot;,&quot;eVar53&quot;:&quot;5301072001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">Transportation Economist
# </a></h2>
# <div class="location">
# <span class="name">
# Mill Creek Building - ODOT, OR
# </span>
# </div>
# <div class="company">
# <span class="name">Oregon Department of Transportation</span>
# <ul class="list-inline">
# </ul>
# </div>
#
# None
# None
# None
#
# <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="559" data-m_impr_j_coc="xtime_nyoscx" data-m_impr_j_jawsid="425967836" data-m_impr_j_jobid="216493284" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="42.6525" data-m_impr_j_lid="544" data-m_impr_j_long="-73.7563" data-m_impr_j_occid="11866" data-m_impr_j_p="2" data-m_impr_j_postingid="9f860997-6841-4cc5-942d-7856190cc6cb" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="75217ea2-2cef-4480-8abe-de16764851b7" href="https://job-openings.monster.com/senior-economist-albany-ny-us-nys-office-of-the-state-comptroller/216493284" onclick="clickJobTitle('plid=544&amp;pcid=559&amp;poccid=11866','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Senior Economist&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xtime_nyoscx_NYS Office of the State Comptroller&quot;,&quot;eVar31&quot;:&quot;Albany_NY_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-03-20T12:00&quot;,&quot;eVar53&quot;:&quot;1900269001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">Senior Economist
# </a></h2>
# <div class="location">
# <span class="name">
# Albany, NY
# </span>
# </div>
# <div class="company">
# <span class="name">NYS Office of the State Comptroller</span>
# <ul class="list-inline">
# </ul>
# </div>
#
# <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="9008" data-m_impr_j_coc="xwmatax" data-m_impr_j_jawsid="426718079" data-m_impr_j_jobid="216685632" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="38.8951" data-m_impr_j_lid="371" data-m_impr_j_long="-77.0364" data-m_impr_j_occid="11910" data-m_impr_j_p="3" data-m_impr_j_postingid="b69a8d9b-d82f-4678-a0fb-4c048114a47d" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="aea80468-3817-4e4e-82a3-7fdaebbf603a" href="https://job-openings.monster.com/sr-transportation-economist-sr-business-intelligence-planner-washington-dc-us-washington-metropolitan-area-transit-authority/216685632" onclick="clickJobTitle('plid=371&amp;pcid=9008&amp;poccid=11910','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Sr. Transportation Economist (Sr. Business Intelligence Planner)&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xwmatax_Washington Metropolitan Area Transit Authority&quot;,&quot;eVar31&quot;:&quot;Washington_DC_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-03-13T12:00&quot;,&quot;eVar53&quot;:&quot;1500144001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;logo&quot;}')">Sr. Transportation Economist (Sr. Business Intelligence Planner)
# </a></h2>
# <div class="location">
# <span class="name">
# Washington, DC
# </span>
# </div>
# <div class="company">
# <span class="name">Washington Metropolitan Area Transit Authority</span>
# <ul class="list-inline">
# </ul>
# </div>
#
# <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="11" data-m_impr_j_coc="xpn600252615_pcarlsx" data-m_impr_j_jawsid="424586741" data-m_impr_j_jobid="216313117" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="39.9616" data-m_impr_j_lid="585" data-m_impr_j_long="-75.1995" data-m_impr_j_occid="11892" data-m_impr_j_p="4" data-m_impr_j_postingid="ae90f5f5-6ad8-4397-b27c-f6acd1b214b6" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="af0c72cc-306d-463a-affd-275de63a9889" href="https://job-openings.monster.com/international-economist-philadelphia-pa-us-university-of-pennsylvania/216313117" onclick="clickJobTitle('plid=585&amp;pcid=11&amp;poccid=11892','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;INTERNATIONAL ECONOMIST&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xpn600252615_pcarlsx_UNIVERSITY OF PENNSYLVANIA&quot;,&quot;eVar31&quot;:&quot;Philadelphia_PA_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-03-01T12:00&quot;,&quot;eVar53&quot;:&quot;1900269001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">INTERNATIONAL ECONOMIST
# </a></h2>
# <div class="location">
# <span class="name">
# Philadelphia, PA
# </span>
# </div>
# <div class="company">
# <span class="name">UNIVERSITY OF PENNSYLVANIA</span>
# <ul class="list-inline">
# </ul>
# </div>
#
# <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="3561" data-m_impr_j_coc="xnyisox" data-m_impr_j_jawsid="423237675" data-m_impr_j_jobid="216090939" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="42.6273" data-m_impr_j_lid="544" data-m_impr_j_long="-73.7089" data-m_impr_j_occid="11895" data-m_impr_j_p="5" data-m_impr_j_postingid="c0d7c8d8-afb0-472e-acdf-1be8b7058344" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="4c0862fb-29cc-4e8c-a3c8-d7692b4f5174" href="https://job-openings.monster.com/economist-rensselaer-ny-us-nyiso/216090939" onclick="clickJobTitle('plid=544&amp;pcid=3561&amp;poccid=11895','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Economist&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xnyisox_NYISO&quot;,&quot;eVar31&quot;:&quot;Rensselaer_NY_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-03-20T12:00&quot;,&quot;eVar53&quot;:&quot;1900269001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;bolded-logo&quot;}')">Economist
# </a></h2>
# <div class="location">
# <span class="name">
# Rensselaer, NY
# </span>
# </div>
# <div class="company">
# <span class="name">NYISO</span>
# <ul class="list-inline">
# </ul>
# </div>
#
# <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="1" data-m_impr_j_coc="xcyberc3x" data-m_impr_j_jawsid="426970177" data-m_impr_j_jobid="216717155" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="41.4995" data-m_impr_j_lid="560" data-m_impr_j_long="-81.6955" data-m_impr_j_occid="11760" data-m_impr_j_p="6" data-m_impr_j_postingid="8f5102a5-a7c6-4df7-b3ea-20618e285238" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="a8303f11-332e-4e8f-b2f5-3eca1d50ea91" href="https://job-openings.monster.com/senior-equity-research-associate-finance-economics-cleveland-oh-us-cybercoders/216717155" onclick="clickJobTitle('plid=560&amp;pcid=1&amp;poccid=11760','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Senior Equity Research Associate - Finance, Economics&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xcyberc3x_CyberCoders&quot;,&quot;eVar31&quot;:&quot;Cleveland_OH_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-03-16T12:00&quot;,&quot;eVar53&quot;:&quot;1900305001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;logo&quot;}')">Senior Equity Research Associate - Finance, Economics
# </a></h2>
# <div class="location">
# <span class="name">
# Cleveland, OH
# </span>
# </div>
# <div class="company">
# <span class="name">CyberCoders</span>
# <ul class="list-inline">
# </ul>
# </div>
#
# None
# None
# None
#
# <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="3" data-m_impr_j_coc="xw288169336wx" data-m_impr_j_jawsid="417720813" data-m_impr_j_jobid="215090143" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="42.8379" data-m_impr_j_lid="530" data-m_impr_j_long="-71.1618" data-m_impr_j_occid="11915" data-m_impr_j_p="7" data-m_impr_j_postingid="462c770e-e8f2-46ba-8b40-55ddfeb10888" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="0b0de47b-346c-42b2-916e-b74a82622f68" href="https://job-openings.monster.com/economics-education-sme-atkinson-nh-us-gex-inc/215090143" onclick="clickJobTitle('plid=530&amp;pcid=3&amp;poccid=11915','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;ECONOMICS EDUCATION SME&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xw288169336wx_GEX, Inc.&quot;,&quot;eVar31&quot;:&quot;ATKINSON_NH_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-03-14T12:00&quot;,&quot;eVar53&quot;:&quot;2500401001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;logo&quot;}')">ECONOMICS EDUCATION SME
# </a></h2>
# <div class="location">
# <span class="name">
# ATKINSON, NH
# </span>
# </div>
# <div class="company">
# <span class="name">GEX, Inc.</span>
# <ul class="list-inline">
# </ul>
# </div>
#
# <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="9008" data-m_impr_j_coc="xhj270_119957x" data-m_impr_j_jawsid="427647264" data-m_impr_j_jobid="216859301" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="42.9652" data-m_impr_j_lid="706" data-m_impr_j_long="-72.9074" data-m_impr_j_occid="11910" data-m_impr_j_p="8" data-m_impr_j_postingid="2f2275c1-3fca-49cb-985e-0b17867b8630" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="2ebe32c4-82ae-43be-b7e5-e7712c73e23a" href="https://job-openings.monster.com/economic-development-director-mount-snow-vt-us-town-of-dover/216859301" onclick="clickJobTitle('plid=706&amp;pcid=9008&amp;poccid=11910','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;ECONOMIC DEVELOPMENT DIRECTOR&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xhj270_119957x_TOWN OF DOVER&quot;,&quot;eVar31&quot;:&quot;Mount Snow_VT_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-03-21T12:00&quot;,&quot;eVar53&quot;:&quot;1100003001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">ECONOMIC DEVELOPMENT DIRECTOR
# </a></h2>
# <div class="location">
# <span class="name">
# Mount Snow, VT
# </span>
# </div>
# <div class="company">
# <span class="name">TOWN OF DOVER</span>
# <ul class="list-inline">
# </ul>
# </div>
#
# <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="9008" data-m_impr_j_coc="xbuff_univofnvx" data-m_impr_j_jawsid="423682262" data-m_impr_j_jobid="216184337" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="36.1095" data-m_impr_j_lid="541" data-m_impr_j_long="-115.1438" data-m_impr_j_occid="11934" data-m_impr_j_p="9" data-m_impr_j_postingid="1223f32e-5717-421c-bfde-31833d16b55f" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="d878ea36-11a5-4a00-9f93-53ad33e5571c" href="https://job-openings.monster.com/project-manager-office-of-economic-development-las-vegas-nv-us-university-of-nevada-las-vegas/216184337" onclick="clickJobTitle('plid=541&amp;pcid=9008&amp;poccid=11934','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Project Manager, Office of Economic Development&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xbuff_univofnvx_University of Nevada, Las Vegas&quot;,&quot;eVar31&quot;:&quot;Las Vegas_NV_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-02-24T12:00&quot;,&quot;eVar53&quot;:&quot;1300093001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">Project Manager, Office of Economic Development
# </a></h2>
# <div class="location">
# <span class="name">
# Las Vegas, NV
# </span>
# </div>
# <div class="company">
# <span class="name">University of Nevada, Las Vegas</span>
# <ul class="list-inline">
# </ul>
# </div>
#
# <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="2" data-m_impr_j_coc="" data-m_impr_j_jawsid="422005526" data-m_impr_j_jobid="0" data-m_impr_j_jpm="1" data-m_impr_j_jpt="2" data-m_impr_j_lat="29.4241" data-m_impr_j_lid="624" data-m_impr_j_long="-98.4937" data-m_impr_j_occid="14874" data-m_impr_j_p="10" data-m_impr_j_postingid="5941e56d-0985-4b4f-b42e-c8ed825cf86b" data-m_impr_j_pvc="27aa7533-7b3b-4108-84cc-8faf5c5bbc61" data-m_impr_s_t="t" data-m_impr_uuid="03379e09-8039-4c6f-ac63-f10689c46c8a" href="https://job-openings.monster.com/vp-real-estate-technology-san-antonio-tx-us-penfed-credit-union/5941e56d-0985-4b4f-b42e-c8ed825cf86b" onclick="clickJobTitle('plid=624&amp;pcid=2&amp;poccid=14874','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;VP Real Estate Technology&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;_PenFed Credit Union&quot;,&quot;eVar31&quot;:&quot;San Antonio_TX_&quot;,&quot;prop24&quot;:&quot;2020-03-16T12:00&quot;,&quot;eVar53&quot;:&quot;1100052001001&quot;,&quot;eVar50&quot;:&quot;PPC&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">VP Real Estate Technology
# </a></h2>
# <div class="location">
# <span class="name">
# San Antonio, TX
# </span>
# </div>
# <div class="company">
# <span class="name">PenFed Credit Union</span>
# <ul class="list-inline">
# </ul>
# </div>
#
# <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSRSEC" data-m_impr_j_cid="9008" data-m_impr_j_coc="xwag2321849x" data-m_impr_j_jawsid="427526412" data-m_impr_j_jobid="216838335" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="47.6388" data-m_impr_j_lid="0" data-m_impr_j_long="-122.37" data-m_impr_j_occid="11910" data-m_impr_j_p="11" data-m_impr_j_postingid="4268b667-41e4-4e82-933f-f866b37befc4" data-m_impr_j_pvc="monster" data-m_impr_s_t="m" data-m_impr_uuid="b26f9364-3e06-4a22-8762-5dc40e0edfb3" href="https://job-openings.monster.com/economist-seattle-wa-us-amazon-corporate-llc/216838335" onclick="clickJobTitle('plid=0&amp;pcid=9008&amp;poccid=11910','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;events.event65&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Economist&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSRSEC&quot;,&quot;eVar26&quot;:&quot;xwag2321849x_Amazon Corporate LLC&quot;,&quot;eVar31&quot;:&quot;Seattle_WA_&quot;,&quot;prop22&quot;:&quot;Full-Time&quot;,&quot;prop24&quot;:&quot;2020-03-20T05:39&quot;,&quot;eVar47&quot;:&quot;monster&quot;,&quot;eVar53&quot;:&quot;1900269001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;logo&quot;}')">Economist
# </a></h2>
# <div class="location">
# <span class="name">
# Seattle, WA
# </span>
# </div>
# <div class="company">
# <span class="name">Amazon Corporate LLC</span>
# <ul class="list-inline">
# </ul>
# </div>
#
# <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="11" data-m_impr_j_coc="xnypax" data-m_impr_j_jawsid="425624315" data-m_impr_j_jobid="216401612" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="41.0339" data-m_impr_j_lid="556" data-m_impr_j_long="-73.763" data-m_impr_j_occid="11892" data-m_impr_j_p="12" data-m_impr_j_postingid="1079a9fd-d526-46e1-8822-e98afbd467dc" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="4e2d6ad3-2f06-4ba8-9aaa-6784d816313d" href="https://job-openings.monster.com/director-product-marketing-white-plains-ny-us-new-york-power-authority/216401612" onclick="clickJobTitle('plid=556&amp;pcid=11&amp;poccid=11892','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Director Product Marketing&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xnypax_New York Power Authority&quot;,&quot;eVar31&quot;:&quot;White Plains_NY_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-03-04T12:00&quot;,&quot;eVar53&quot;:&quot;1100007001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;logo&quot;}')">Director Product Marketing
# </a></h2>
# <div class="location">
# <span class="name">
# White Plains, NY
# </span>
# </div>
# <div class="company">
# <span class="name">New York Power Authority</span>
# <ul class="list-inline">
# </ul>
# </div>
#
# <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="11" data-m_impr_j_coc="xtacworldx" data-m_impr_j_jawsid="427344929" data-m_impr_j_jobid="216803807" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="42.3298" data-m_impr_j_lid="470" data-m_impr_j_long="-83.1861" data-m_impr_j_occid="11892" data-m_impr_j_p="13" data-m_impr_j_postingid="162373da-ff50-44bf-beff-d5b68c054763" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="a6833009-20a2-4f44-bc98-810e3b4f63ec" href="https://job-openings.monster.com/sales-planning-analytics-dearborn-mi-us-advantage-resourcing/216803807" onclick="clickJobTitle('plid=470&amp;pcid=11&amp;poccid=11892','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Sales Planning Analytics&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xtacworldx_Advantage Resourcing&quot;,&quot;eVar31&quot;:&quot;Dearborn_MI_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-03-19T12:00&quot;,&quot;eVar53&quot;:&quot;4100683001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;logo&quot;}')">Sales Planning Analytics
# </a></h2>
# <div class="location">
# <span class="name">
# Dearborn, MI
# </span>
# </div>
# <div class="company">
# <span class="name">Advantage Resourcing</span>
# <ul class="list-inline">
# </ul>
# </div>
#
# <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="9008" data-m_impr_j_coc="" data-m_impr_j_jawsid="426263948" data-m_impr_j_jobid="389139" data-m_impr_j_jpm="1" data-m_impr_j_jpt="2" data-m_impr_j_lat="42.3314" data-m_impr_j_lid="470" data-m_impr_j_long="-83.0503" data-m_impr_j_occid="11934" data-m_impr_j_p="14" data-m_impr_j_postingid="c8f88771-a8fa-49c1-b6da-bb396d78f9ac" data-m_impr_j_pvc="e8e7415b-3f42-402b-9bc9-401a7ab9203c" data-m_impr_s_t="t" data-m_impr_uuid="e7386523-61b0-49b1-ae8f-05d37c391cc6" href="https://job-openings.monster.com/loss-analyst-detroit-mi-us-quicken-loans/c8f88771-a8fa-49c1-b6da-bb396d78f9ac" onclick="clickJobTitle('plid=470&amp;pcid=9008&amp;poccid=11934','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Loss Analyst&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;_Quicken Loans&quot;,&quot;eVar31&quot;:&quot;Detroit_MI_&quot;,&quot;prop24&quot;:&quot;2020-03-18T12:00&quot;,&quot;eVar53&quot;:&quot;1300093001001&quot;,&quot;eVar50&quot;:&quot;PPC&quot;,&quot;eVar74&quot;:&quot;logo&quot;}')">Loss Analyst
# </a></h2>
# <div class="location">
# <span class="name">
# Detroit, MI
# </span>
# </div>
# <div class="company">
# <span class="name">Quicken Loans</span>
# <ul class="list-inline">
# </ul>
# </div>
#
# <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="11" data-m_impr_j_coc="xsphterex" data-m_impr_j_jawsid="423634471" data-m_impr_j_jobid="216170327" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="47.6739" data-m_impr_j_lid="896" data-m_impr_j_long="-122.1216" data-m_impr_j_occid="11892" data-m_impr_j_p="15" data-m_impr_j_postingid="6b868ecc-99b3-4d11-af7f-9cd2063116d5" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="be6f78bf-5cd4-4011-8b35-cc7ca5a5c4dc" href="https://job-openings.monster.com/global-forecasting-economic-planning-manager-redmond-wa-us-terex-corporation/216170327" onclick="clickJobTitle('plid=896&amp;pcid=11&amp;poccid=11892','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Global Forecasting \u0026 Economic Planning Manager&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xsphterex_Terex Corporation&quot;,&quot;eVar31&quot;:&quot;Redmond_WA_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-03-09T12:00&quot;,&quot;eVar53&quot;:&quot;1101115002005&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">Global Forecasting &amp; Economic Planning Manager
# </a></h2>
# <div class="location">
# <span class="name">
# Redmond, WA
# </span>
# </div>
# <div class="company">
# <span class="name">Terex Corporation</span>
# <ul class="list-inline">
# </ul>
# </div>
#
# <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="3" data-m_impr_j_coc="x559948HJSx" data-m_impr_j_jawsid="424537800" data-m_impr_j_jobid="216321892" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="35.7721" data-m_impr_j_lid="516" data-m_impr_j_long="-78.6387" data-m_impr_j_occid="11995" data-m_impr_j_p="16" data-m_impr_j_postingid="6df3953f-0a98-4db1-8999-729c79992e00" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="f21f64e8-114d-48b6-a530-33697677cda9" href="https://job-openings.monster.com/postdoctoral-research-scholar-raleigh-nc-us-north-carolina-state-univ/216321892" onclick="clickJobTitle('plid=516&amp;pcid=3&amp;poccid=11995','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Postdoctoral Research Scholar&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;x559948HJSx_North Carolina State Univ.&quot;,&quot;eVar31&quot;:&quot;Raleigh_NC_&quot;,&quot;prop24&quot;:&quot;2020-02-29T12:00&quot;,&quot;eVar53&quot;:&quot;2500373001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">Postdoctoral Research Scholar
# </a></h2>
# <div class="location">
# <span class="name">
# Raleigh, NC
# </span>
# </div>
# <div class="company">
# <span class="name">North Carolina State Univ.</span>
# <ul class="list-inline">
# </ul>
# </div>
#
# None
# None
# None
#
# <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="660" data-m_impr_j_coc="xwebxlx" data-m_impr_j_jawsid="426068801" data-m_impr_j_jobid="216545342" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="33.4483" data-m_impr_j_lid="338" data-m_impr_j_long="-112.0741" data-m_impr_j_occid="11904" data-m_impr_j_p="17" data-m_impr_j_postingid="b707f43d-dae6-4f95-ac27-bec46ab354fa" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="448c070c-5210-495a-b8b0-ff57b5044113" href="https://job-openings.monster.com/senior-financial-analyst-phoenix-az-us-collabera/216545342" onclick="clickJobTitle('plid=338&amp;pcid=660&amp;poccid=11904','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Senior Financial Analyst&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xwebxlx_Collabera&quot;,&quot;eVar31&quot;:&quot;Phoenix_AZ_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-03-21T12:00&quot;,&quot;eVar53&quot;:&quot;1300108001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;logo&quot;}')">Senior Financial Analyst
# </a></h2>
# <div class="location">
# <span class="name">
# Phoenix, AZ
# </span>
# </div>
# <div class="company">
# <span class="name">Collabera</span>
# <ul class="list-inline">
# </ul>
# </div>
#
# <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="559" data-m_impr_j_coc="" data-m_impr_j_jawsid="414125802" data-m_impr_j_jobid="218291" data-m_impr_j_jpm="1" data-m_impr_j_jpt="2" data-m_impr_j_lat="39.8912" data-m_impr_j_lid="363" data-m_impr_j_long="-105.1205" data-m_impr_j_occid="11866" data-m_impr_j_p="18" data-m_impr_j_postingid="66dd6c61-5da4-4eb5-992a-2fbf2021a512" data-m_impr_j_pvc="recruiticscenturylink" data-m_impr_s_t="t" data-m_impr_uuid="2204ff9f-1091-4fdd-a142-9ce5bafe7607" href="https://job-openings.monster.com/lead-data-scientist-broomfield-co-us-centurylink/66dd6c61-5da4-4eb5-992a-2fbf2021a512" onclick="clickJobTitle('plid=363&amp;pcid=559&amp;poccid=11866','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Lead Data Scientist&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;_CenturyLink&quot;,&quot;eVar31&quot;:&quot;BROOMFIELD_CO_&quot;,&quot;prop24&quot;:&quot;2020-03-21T12:00&quot;,&quot;eVar53&quot;:&quot;1500152001001&quot;,&quot;eVar50&quot;:&quot;PPC&quot;,&quot;eVar74&quot;:&quot;logo&quot;}')">Lead Data Scientist
# </a></h2>
# <div class="location">
# <span class="name">
# BROOMFIELD, CO
# </span>
# </div>
# <div class="company">
# <span class="name">CenturyLink</span>
# <ul class="list-inline">
# </ul>
# </div>
#
# <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="11" data-m_impr_j_coc="x685177hjsx" data-m_impr_j_jawsid="427532883" data-m_impr_j_jobid="216843389" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="18.25" data-m_impr_j_lid="315" data-m_impr_j_long="-66.5" data-m_impr_j_occid="11892" data-m_impr_j_p="19" data-m_impr_j_postingid="e7e8b53f-3165-4d36-80d1-67e5b3283470" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="f49f9ab3-afc4-4cd9-82ce-e56143ebf9f2" href="https://job-openings.monster.com/associate-manager-commercial-intelligence-pr-us-hersheycareers/216843389" onclick="clickJobTitle('plid=315&amp;pcid=11&amp;poccid=11892','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Associate Manager -  Commercial Intelligence&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;x685177hjsx_HersheyCareers&quot;,&quot;eVar31&quot;:&quot;_PR_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-03-20T12:00&quot;,&quot;eVar53&quot;:&quot;1100055001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">Associate Manager -  Commercial Intelligence
# </a></h2>
# <div class="location">
# <span class="name">
# PR
# </span>
# </div>
# <div class="company">
# <span class="name">HersheyCareers</span>
# <ul class="list-inline">
# </ul>
# </div>
#
# <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="660" data-m_impr_j_coc="xsphetradex" data-m_impr_j_jawsid="427520734" data-m_impr_j_jobid="216832845" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="38.9069" data-m_impr_j_lid="895" data-m_impr_j_long="-77.1236" data-m_impr_j_occid="11904" data-m_impr_j_p="20" data-m_impr_j_postingid="96631056-224c-4dd0-a3ea-e2e011493f7a" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="66ba088b-dc27-4e0f-9b2f-9c16c0b195ee" href="https://job-openings.monster.com/senior-analyst-control-testing-services-arlington-va-us-e-trade/216832845" onclick="clickJobTitle('plid=895&amp;pcid=660&amp;poccid=11904','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Senior Analyst, Control Testing Services&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xsphetradex_E-TRADE&quot;,&quot;eVar31&quot;:&quot;Arlington_VA_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-03-20T12:00&quot;,&quot;eVar53&quot;:&quot;1900306001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">Senior Analyst, Control Testing Services
# </a></h2>
# <div class="location">
# <span class="name">
# Arlington, VA
# </span>
# </div>
# <div class="company">
# <span class="name">E-TRADE</span>
# <ul class="list-inline">
# </ul>
# </div>
#
# <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="1" data-m_impr_j_coc="xmyhrx" data-m_impr_j_jawsid="427563703" data-m_impr_j_jobid="216852703" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="40.7286" data-m_impr_j_lid="532" data-m_impr_j_long="-74.0775" data-m_impr_j_occid="11893" data-m_impr_j_p="21" data-m_impr_j_postingid="808c87a5-6301-4ea3-8f04-fed8d233b7e6" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="3f3b7967-b67a-46cf-bba6-abf2ec5dd6c7" href="https://job-openings.monster.com/model-risk-director-quant-model-validation-jersey-city-nj-us-my-hr-supplier/216852703" onclick="clickJobTitle('plid=532&amp;pcid=1&amp;poccid=11893','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Model Risk Director (Quant Model Validation)&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xmyhrx_MY HR Supplier&quot;,&quot;eVar31&quot;:&quot;Jersey City_NJ_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-03-20T12:00&quot;,&quot;eVar53&quot;:&quot;1100014001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">Model Risk Director (Quant Model Validation)
# </a></h2>
# <div class="location">
# <span class="name">
# Jersey City, NJ
# </span>
# </div>
# <div class="company">
# <span class="name">MY HR Supplier</span>
# <ul class="list-inline">
# </ul>
# </div>
#
# <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="1" data-m_impr_j_coc="xadptotalx" data-m_impr_j_jawsid="423359005" data-m_impr_j_jobid="216131754" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="41.678" data-m_impr_j_lid="890" data-m_impr_j_long="-88.1448" data-m_impr_j_occid="11981" data-m_impr_j_p="22" data-m_impr_j_postingid="61e072ff-4b87-4693-96a1-4a115310c7b6" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="402709b5-4d60-4d94-8980-7266bbb276a8" href="https://job-openings.monster.com/tax-specialist-bolingbrook-il-us-beko-us-inc/216131754" onclick="clickJobTitle('plid=890&amp;pcid=1&amp;poccid=11981','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Tax Specialist&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xadptotalx_BEKO US INC&quot;,&quot;eVar31&quot;:&quot;Bolingbrook_IL_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-03-20T12:00&quot;,&quot;eVar53&quot;:&quot;1300116001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">Tax Specialist
# </a></h2>
# <div class="location">
# <span class="name">
# Bolingbrook, IL
# </span>
# </div>
# <div class="company">
# <span class="name">BEKO US INC</span>
# <ul class="list-inline">
# </ul>
# </div>
#
# <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="11" data-m_impr_j_coc="xsphcobhamx" data-m_impr_j_jawsid="427530711" data-m_impr_j_jobid="216841798" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="32.7153" data-m_impr_j_lid="354" data-m_impr_j_long="-117.1573" data-m_impr_j_occid="11892" data-m_impr_j_p="23" data-m_impr_j_postingid="59c84b4d-017a-4581-bd85-c6b39ff7916d" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="1684eb95-6aba-42f5-accb-03a0dbe65a16" href="https://job-openings.monster.com/project-program-control-analyst-san-diego-ca-us-cobham/216841798" onclick="clickJobTitle('plid=354&amp;pcid=11&amp;poccid=11892','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Project / Program Control Analyst&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xsphcobhamx_Cobham&quot;,&quot;eVar31&quot;:&quot;San Diego_CA_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-03-20T12:00&quot;,&quot;eVar53&quot;:&quot;1300093001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">Project / Program Control Analyst
# </a></h2>
# <div class="location">
# <span class="name">
# San Diego, CA
# </span>
# </div>
# <div class="company">
# <span class="name">Cobham</span>
# <ul class="list-inline">
# </ul>
# </div>
#
# <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="11" data-m_impr_j_coc="xsphhoneyx" data-m_impr_j_jawsid="425920656" data-m_impr_j_jobid="216472289" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="33.8358" data-m_impr_j_lid="348" data-m_impr_j_long="-118.3407" data-m_impr_j_occid="11892" data-m_impr_j_p="24" data-m_impr_j_postingid="2bc10bbe-5f56-4ae6-ad3f-dcc0491fdc50" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="8d1fc930-f80a-462e-a6ee-d8a97864b7af" href="https://job-openings.monster.com/program-planning-control-analyst-iii-torrance-ca-us-honeywell/216472289" onclick="clickJobTitle('plid=348&amp;pcid=11&amp;poccid=11892','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Program Planning \u0026 Control Analyst III&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xsphhoneyx_Honeywell&quot;,&quot;eVar31&quot;:&quot;Torrance_CA_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-03-20T12:00&quot;,&quot;eVar53&quot;:&quot;1300093001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">Program Planning &amp; Control Analyst III
# </a></h2>
# <div class="location">
# <span class="name">
# Torrance, CA
# </span>
# </div>
# <div class="company">
# <span class="name">Honeywell</span>
# <ul class="list-inline">
# </ul>
# </div>
#
# <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="1" data-m_impr_j_coc="xw146445879wx" data-m_impr_j_jawsid="426455680" data-m_impr_j_jobid="216621046" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="40.6527" data-m_impr_j_lid="534" data-m_impr_j_long="-74.2601" data-m_impr_j_occid="11817" data-m_impr_j_p="25" data-m_impr_j_postingid="a5e0995e-fb83-447e-8020-7a8925f6cd1b" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="d2845330-4fa9-437b-abc2-8291c6dac1d9" href="https://job-openings.monster.com/staff-accountant-roselle-nj-us-pamarco-global-graphics/216621046" onclick="clickJobTitle('plid=534&amp;pcid=1&amp;poccid=11817','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Staff Accountant&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xw146445879wx_Pamarco Global Graphics&quot;,&quot;eVar31&quot;:&quot;Roselle_NJ_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-03-19T12:00&quot;,&quot;eVar53&quot;:&quot;1300101001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">Staff Accountant
# </a></h2>
# <div class="location">
# <span class="name">
# Roselle, NJ
# </span>
# </div>
# <div class="company">
# <span class="name">Pamarco Global Graphics</span>
# <ul class="list-inline">
# </ul>
# </div>
#
# <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="5623" data-m_impr_j_coc="xlnpmediax" data-m_impr_j_jawsid="427364927" data-m_impr_j_jobid="216812628" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="40.0115" data-m_impr_j_lid="703" data-m_impr_j_long="-76.3553" data-m_impr_j_occid="11781" data-m_impr_j_p="26" data-m_impr_j_postingid="486cdfe5-11fa-4c06-9822-78558b69f437" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="a553507a-ccae-4a2a-b8d6-4df20affd3ae" href="https://job-openings.monster.com/business-editor-lancaster-pa-us-lnp-media-group/216812628" onclick="clickJobTitle('plid=703&amp;pcid=5623&amp;poccid=11781','Economist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Business Editor&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xlnpmediax_LNP Media Group&quot;,&quot;eVar31&quot;:&quot;Lancaster_PA_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-03-19T12:00&quot;,&quot;eVar53&quot;:&quot;2700439001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">Business Editor
# </a></h2>
# <div class="location">
# <span class="name">
# Lancaster, PA
# </span>
# </div>
# <div class="company">
# <span class="name">LNP Media Group</span>
# <ul class="list-inline">
# </ul>
# </div>

# %% [markdown]
# Looks more trimmed. You still want to clean that up. **How do you extract text from the HTML element?**

# %% [markdown]
# ### Extract text from the parsed HTML

# %%
for job_elem in job_elems:
    title_elem = job_elem.find('h2', class_='title')
    company_elem = job_elem.find('div', class_='company')
    location_elem = job_elem.find('div', class_='location')
    if None in (title_elem, company_elem, location_elem): #tell Python to skip that iteration if the job listing does not contain the information you want
        continue
    print(title_elem.text)
    print(company_elem.text)
    print(location_elem.text)
    print()
# Out:
# Transportation Economist
#
#
# Oregon Department of Transportation
#
#
#
#
#
# Mill Creek Building - ODOT, OR
#
#
#
# Senior Economist
#
#
# NYS Office of the State Comptroller
#
#
#
#
#
# Albany, NY
#
#
#
# Sr. Transportation Economist (Sr. Business Intelligence Planner)
#
#
# Washington Metropolitan Area Transit Authority
#
#
#
#
#
# Washington, DC
#
#
#
# INTERNATIONAL ECONOMIST
#
#
# UNIVERSITY OF PENNSYLVANIA
#
#
#
#
#
# Philadelphia, PA
#
#
#
# Economist
#
#
# NYISO
#
#
#
#
#
# Rensselaer, NY
#
#
#
# Senior Equity Research Associate - Finance, Economics
#
#
# CyberCoders
#
#
#
#
#
# Cleveland, OH
#
#
#
# ECONOMICS EDUCATION SME
#
#
# GEX, Inc.
#
#
#
#
#
# ATKINSON, NH
#
#
#
# ECONOMIC DEVELOPMENT DIRECTOR
#
#
# TOWN OF DOVER
#
#
#
#
#
# Mount Snow, VT
#
#
#
# Project Manager, Office of Economic Development
#
#
# University of Nevada, Las Vegas
#
#
#
#
#
# Las Vegas, NV
#
#
#
# VP Real Estate Technology
#
#
# PenFed Credit Union
#
#
#
#
#
# San Antonio, TX
#
#
#
# Economist
#
#
# Amazon Corporate LLC
#
#
#
#
#
# Seattle, WA
#
#
#
# Director Product Marketing
#
#
# New York Power Authority
#
#
#
#
#
# White Plains, NY
#
#
#
# Sales Planning Analytics
#
#
# Advantage Resourcing
#
#
#
#
#
# Dearborn, MI
#
#
#
# Loss Analyst
#
#
# Quicken Loans
#
#
#
#
#
# Detroit, MI
#
#
#
# Global Forecasting & Economic Planning Manager
#
#
# Terex Corporation
#
#
#
#
#
# Redmond, WA
#
#
#
# Postdoctoral Research Scholar
#
#
# North Carolina State Univ.
#
#
#
#
#
# Raleigh, NC
#
#
#
# Senior Financial Analyst
#
#
# Collabera
#
#
#
#
#
# Phoenix, AZ
#
#
#
# Lead Data Scientist
#
#
# CenturyLink
#
#
#
#
#
# BROOMFIELD, CO
#
#
#
# Associate Manager -  Commercial Intelligence
#
#
# HersheyCareers
#
#
#
#
#
# PR
#
#
#
# Senior Analyst, Control Testing Services
#
#
# E-TRADE
#
#
#
#
#
# Arlington, VA
#
#
#
# Model Risk Director (Quant Model Validation)
#
#
# MY HR Supplier
#
#
#
#
#
# Jersey City, NJ
#
#
#
# Tax Specialist
#
#
# BEKO US INC
#
#
#
#
#
# Bolingbrook, IL
#
#
#
# Project / Program Control Analyst
#
#
# Cobham
#
#
#
#
#
# San Diego, CA
#
#
#
# Program Planning & Control Analyst III
#
#
# Honeywell
#
#
#
#
#
# Torrance, CA
#
#
#
# Staff Accountant
#
#
# Pamarco Global Graphics
#
#
#
#
#
# Roselle, NJ
#
#
#
# Business Editor
#
#
# LNP Media Group
#
#
#
#
#
# Lancaster, PA

# %% [markdown]
# Now, it looks **absolutely beautiful** ! You can do more with that. Assume you are not interested in anything else than Python developer jobs. You can just tell BeautifulSoup to filter elements that contain this word in the job title part.

# %%
econ_jobs = results.find_all('h2',
                               string=lambda text: 'economist' in text.lower())

# %%
print(len(econ_jobs))
# Out:
# 6

# %% [markdown]
# ### Extract attributes from the parsed HTML

# %% [markdown]
# Now, you want also the link to that job (your goal is to apply !). The link is in the element with the "title" class. You can see that it's in the `<a>` tag. The `<a>` tag has some attributes. Among those, you have one called `href` : this is the link. Fetch it.

# %%
for e_job in econ_jobs:
    link = e_job.find('a')['href']
    print(f"Apply here: {link}\n")
# Out:
# Apply here: https://job-openings.monster.com/transportation-economist-mill-creek-building-odot-or-us-oregon-department-of-transportation/216739002
#
# Apply here: https://job-openings.monster.com/senior-economist-albany-ny-us-nys-office-of-the-state-comptroller/216493284
#
# Apply here: https://job-openings.monster.com/sr-transportation-economist-sr-business-intelligence-planner-washington-dc-us-washington-metropolitan-area-transit-authority/216685632
#
# Apply here: https://job-openings.monster.com/international-economist-philadelphia-pa-us-university-of-pennsylvania/216313117
#
# Apply here: https://job-openings.monster.com/economist-rensselaer-ny-us-nyiso/216090939
#
# Apply here: https://job-openings.monster.com/economist-seattle-wa-us-amazon-corporate-llc/216838335

# %% [markdown]
# Beautiful, right?  😃
